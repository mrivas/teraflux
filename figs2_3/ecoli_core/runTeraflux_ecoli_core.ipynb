# %%
import cobra
from cobra.io import load_model, read_sbml_model
from cobra.flux_analysis import flux_variability_analysis
import pandas as pd
import scipy
from scipy.stats import pearsonr
import numpy as np
import matplotlib.pyplot as plt
import importlib
import gc
from cobra.sampling import sample
from matplotlib.ticker import MaxNLocator

# %%
import sys
teraflux_path = '../../'
if teraflux_path not in sys.path:
    sys.path.append(teraflux_path)
import teraflux
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
organism="Ecoli_core"

# %%
model = load_model("textbook")
# Update gene protein rule wit the reaction ID
for reaction in model.reactions:
    reaction.gene_reaction_rule = reaction.id

# %%
cobra.io.write_sbml_model(model, "ecoli_core.xml")

# %%
# DO SAMPLING

# %%
BOUND=30000
modelS = load_model("textbook")
for reaction in modelS.reactions:
    LB, UB = reaction.bounds
    if LB==-1000: LB = -BOUND
    if UB== 1000: UB =  BOUND
    reaction.bounds=(LB,UB)
modelS.reactions.EX_glc__D_e.bounds = (-10,BOUND)
modelS.reactions.ATPM.bounds = (0,BOUND)
s = sample(modelS, 1000)
s.to_csv('sampled_flux_distributions.csv')

# %%
s = pd.read_csv('sampled_flux_distributions.csv',index_col=0)

# %%
import pandas as pd
import os # 1. Import the 'os' module for directory and path operations

# 2. Define the names of the new directories
known_fluxes_dir = 'knownFluxes'
transcriptomes_dir = 'transcriptomes'

# Create the directories before the loop starts.
# 'exist_ok=True' prevents an error if the directories already exist.
os.makedirs(known_fluxes_dir, exist_ok=True)
os.makedirs(transcriptomes_dir, exist_ok=True)
print(f"Ensured directories '{known_fluxes_dir}' and '{transcriptomes_dir}' exist.")


# Open the inputData.csv file once, BEFORE the loop begins.
with open("inputData.csv", 'w', newline="\n") as input_data_file:
    # Write the header to the main file just one time.
    print("Organism", "Condition", "GeneExpFile", "Medium", "Network", "KnownFluxes", sep="\t", file=input_data_file)

    # Now, start the loop to process each row and append to the file.
    for i in range(s.shape[0]):
        
        fluxesRef = s.loc[i]
        expressions = fluxesRef.abs()

        # --- Create iteration-specific files inside their respective folders ---
        
        # 3. Use os.path.join() to create the full path for each file.
        # This correctly adds the folder name to the path.
        known_fluxes_filename = os.path.join(known_fluxes_dir, f'knownFluxes_{i}.csv')
        transcriptome_filename = os.path.join(transcriptomes_dir, f'transcriptome_{i}.csv')

        # Create the knownFluxes file for the current iteration
        with open(known_fluxes_filename, 'w', newline="\n") as f:
            print("Reaction_ID", "Metabolite_ID", "Reaction_Flux", sep="\t", file=f)
            intakeRxns = ["EX_glc__D_e"]
            for Reaction_ID in intakeRxns:
                Metabolite_ID = Reaction_ID[3::]
                Reaction_Flux = fluxesRef[Reaction_ID]
                print(Reaction_ID, Metabolite_ID, Reaction_Flux, sep="\t", file=f)
        
        # Create the transcriptome file for the current iteration
        with open(transcriptome_filename, 'w', newline="\n") as f:
            print("Gene_ID", "Expression", sep="\t", file=f)
            for reactionID in expressions.index:
                print(reactionID, expressions[reactionID], sep="\t", file=f)
        
        # --- Append a new line to the main inputData.csv file ---
        
        # The variables now hold the full paths (e.g., "knownFluxes/knownFluxes_0.csv")
        # so this part works perfectly without further changes.
        Organism = organism
        Condition = f"glucose_iter_{i}"
        GeneExpFile = transcriptome_filename
        Medium = "medium.csv"
        Network = "ecoli_core.xml"
        KnownFluxes = known_fluxes_filename
        
        # Print the new line to the already-open input_data_file
        print(Organism, Condition, GeneExpFile, Medium, Network, KnownFluxes, sep="\t", file=input_data_file)

print("\nProcessing complete. 'inputData.csv' and sub-folder files have been created.")
# Out:
# Ensured directories 'knownFluxes' and 'transcriptomes' exist.
#
# Processing complete. 'inputData.csv' and sub-folder files have been created.

# %%
inputFile = "inputData.csv"
resultsDir = "./results"
prefix_log_file="teraflux_ecolicore"
fluxes=teraflux.getFluxes(inputFile,resultsDir,prefix_log_file)
# Out:
# Found 1000 conditions to process.
#
# ==================== STARTING: Ecoli_core - glucose_iter_0 =====================
# [2026/02/06 19:28:43] Loading metabolic model: ecoli_core.xml
# [2026/02/06 19:28:43] Loading transcriptomic data: transcriptome_0.csv
# [2026/02/06 19:28:43] Loading known fluxes: knownFluxes_0.csv
# [2026/02/06 19:28:43] Updating model (bounds, medium)...
# Applying medium from: medium.csv
# Starting data pre-processing...
# Capping FPKM values at 95th percentile: 80.5596
# Median 'g' value (E_g) for imputation: 3.1127e+00
# Pre-processing finished in 0.01 seconds.
# [2026/02/06 19:28:45] Running TeraFlux optimization...
# Creating stoichiometric constraints...
# Adding known flux constraints...
# Solving with standard FBA to get an initial guess (x0)...
# Adding known flux constraints...
# R_EX_glc__D_e -9.879681412354817
# {'R_EX_glc__D_e': 9.879681412354817, 'R_EX_nh4_e': inf, 'R_EX_o2_e': inf, 'R_EX_pi_e': inf}
# FBA solution found. Objective value: 0.9056. Status: optimal
# ## Solving the non-linear optimization problem with IPOPT...
# Solver finished. Status: Solve_Succeeded | Success: True
# Optimization took: 0.04 s
# [2026/02/06 19:28:46] Saving results...
# [2026/02/06 19:28:46] Ecoli_core - glucose_iter_0 processed.
# ================================================================================
#
# ==================== STARTING: Ecoli_core - glucose_iter_1 =====================
# [2026/02/06 19:28:46] Loading metabolic model: ecoli_core.xml
# [2026/02/06 19:28:46] Loading transcriptomic data: transcriptome_1.csv
# [2026/02/06 19:28:46] Loading known fluxes: knownFluxes_1.csv
# [2026/02/06 19:28:46] Updating model (bounds, medium)...
# Applying medium from: medium.csv
# Starting data pre-processing...
# Capping FPKM values at 95th percentile: 59.8640
# Median 'g' value (E_g) for imputation: 4.8247e+00
# Pre-processing finished in 0.00 seconds.
# [2026/02/06 19:28:46] Running TeraFlux optimization...
# Creating stoichiometric constraints...
# Adding known flux constraints...
# Solving with standard FBA to get an initial guess (x0)...
# Adding known flux constraints...
# R_EX_glc__D_e -9.948971113894114
# {'R_EX_glc__D_e': 9.948971113894114, 'R_EX_nh4_e': inf, 'R_EX_o2_e': inf, 'R_EX_pi_e': inf}
# FBA solution found. Objective value: 0.9120. Status: optimal
# ## Solving the non-linear optimization problem with IPOPT...
# Solver finished. Status: Solve_Succeeded | Success: True
# Optimization took: 0.03 s
# [2026/02/06 19:28:46] Saving results...
# [2026/02/06 19:28:46] Ecoli_core - glucose_iter_1 processed.
# ================================================================================
#
# ==================== STARTING: Ecoli_core - glucose_iter_2 =====================
# [2026/02/06 19:28:46] Loading metabolic model: ecoli_core.xml
# [2026/02/06 19:28:46] Loading transcriptomic data: transcriptome_2.csv
# [2026/02/06 19:28:46] Loading known fluxes: knownFluxes_2.csv
# [2026/02/06 19:28:46] Updating model (bounds, medium)...
# Applying medium from: medium.csv
# Starting data pre-processing...
# Capping FPKM values at 95th percentile: 41.9571
# Median 'g' value (E_g) for imputation: 3.2119e+00
# Pre-processing finished in 0.00 seconds.
# [2026/02/06 19:28:46] Running TeraFlux optimization...
# Creating stoichiometric constraints...
# Adding known flux constraints...
# Solving with standard FBA to get an initial guess (x0)...
# Adding known flux constraints...
# R_EX_glc__D_e -9.7836974526578
# {'R_EX_glc__D_e': 9.7836974526578, 'R_EX_nh4_e': inf, 'R_EX_o2_e': inf, 'R_EX_pi_e': inf}
# FBA solution found. Objective value: 0.8968. Status: optimal
# ## Solving the non-linear optimization problem with IPOPT...
# Solver finished. Status: Solve_Succeeded | Success: True
# Optimization took: 0.03 s
# [2026/02/06 19:28:46] Saving results...
# [2026/02/06 19:28:46] Ecoli_core - glucose_iter_2 processed.
# ================================================================================
#
# ==================== STARTING: Ecoli_core - glucose_iter_3 =====================
# [2026/02/06 19:28:46] Loading metabolic model: ecoli_core.xml
# [2026/02/06 19:28:46] Loading transcriptomic data: transcriptome_3.csv
# [2026/02/06 19:28:46] Loading known fluxes: knownFluxes_3.csv
# [2026/02/06 19:28:46] Updating model (bounds, medium)...
# Applying medium from: medium.csv
# Starting data pre-processing...
# Capping FPKM values at 95th percentile: 55.1245
# Median 'g' value (E_g) for imputation: 4.1482e+00
# Pre-processing finished in 0.00 seconds.
# [2026/02/06 19:28:46] Running TeraFlux optimization...
# Creating stoichiometric constraints...
# Adding known flux constraints...
# Solving with standard FBA to get an initial guess (x0)...
# Adding known flux constraints...
# R_EX_glc__D_e -9.930910859813624
# {'R_EX_glc__D_e': 9.930910859813624, 'R_EX_nh4_e': inf, 'R_EX_o2_e': inf, 'R_EX_pi_e': inf}
# FBA solution found. Objective value: 0.9103. Status: optimal
# ## Solving the non-linear optimization problem with IPOPT...
# Solver finished. Status: Solve_Succeeded | Success: True
# Optimization took: 0.04 s
# [2026/02/06 19:28:46] Saving results...
# [2026/02/06 19:28:46] Ecoli_core - glucose_iter_3 processed.
# ================================================================================
#
# ==================== STARTING: Ecoli_core - glucose_iter_4 =====================
# [2026/02/06 19:28:46] Loading metabolic model: ecoli_core.xml
# [2026/02/06 19:28:46] Loading transcriptomic data: transcriptome_4.csv
# [2026/02/06 19:28:46] Loading known fluxes: knownFluxes_4.csv
# [2026/02/06 19:28:46] Updating model (bounds, medium)...
# Applying medium from: medium.csv
# Starting data pre-processing...
# Capping FPKM values at 95th percentile: 45.0094
# Median 'g' value (E_g) for imputation: 4.7970e+00
# Pre-processing finished in 0.00 seconds.
# [2026/02/06 19:28:47] Running TeraFlux optimization...
# Creating stoichiometric constraints...
# Adding known flux constraints...
# Solving with standard FBA to get an initial guess (x0)...
# Adding known flux constraints...
# R_EX_glc__D_e -9.918952169977317
# {'R_EX_glc__D_e': 9.918952169977317, 'R_EX_nh4_e': inf, 'R_EX_o2_e': inf, 'R_EX_pi_e': inf}
# FBA solution found. Objective value: 0.9092. Status: optimal
# ## Solving the non-linear optimization problem with IPOPT...
# Solver finished. Status: Solve_Succeeded | Success: True
# Optimization took: 0.03 s
# [2026/02/06 19:28:47] Saving results...
# [2026/02/06 19:28:47] Ecoli_core - glucose_iter_4 processed.
# ================================================================================
#
# ==================== STARTING: Ecoli_core - glucose_iter_5 =====================
# [2026/02/06 19:28:47] Loading metabolic model: ecoli_core.xml
# [2026/02/06 19:28:47] Loading transcriptomic data: transcriptome_5.csv
# [2026/02/06 19:28:47] Loading known fluxes: knownFluxes_5.csv
# [2026/02/06 19:28:47] Updating model (bounds, medium)...
# Applying medium from: medium.csv
# Starting data pre-processing...
# Capping FPKM values at 95th percentile: 50.6815
# Median 'g' value (E_g) for imputation: 2.7477e+00
# Pre-processing finished in 0.00 seconds.
# [2026/02/06 19:28:47] Running TeraFlux optimization...
# Creating stoichiometric constraints...
# Adding known flux constraints...
# Solving with standard FBA to get an initial guess (x0)...
# Adding known flux constraints...
# R_EX_glc__D_e -9.901387822547903
# {'R_EX_glc__D_e': 9.901387822547903, 'R_EX_nh4_e': inf, 'R_EX_o2_e': inf, 'R_EX_pi_e': inf}
# FBA solution found. Objective value: 0.9076. Status: optimal
# ## Solving the non-linear optimization problem with IPOPT...
# Solver finished. Status: Solve_Succeeded | Success: True
# Optimization took: 0.03 s
# [2026/02/06 19:28:47] Saving results...
# [2026/02/06 19:28:47] Ecoli_core - glucose_iter_5 processed.
# ================================================================================
#
# ==================== STARTING: Ecoli_core - glucose_iter_6 =====================
# [2026/02/06 19:28:47] Loading metabolic model: ecoli_core.xml
# [2026/02/06 19:28:47] Loading transcriptomic data: transcriptome_6.csv
# [2026/02/06 19:28:47] Loading known fluxes: knownFluxes_6.csv
# [2026/02/06 19:28:47] Updating model (bounds, medium)...
# Applying medium from: medium.csv
# Starting data pre-processing...
# Capping FPKM values at 95th percentile: 60.2140
# Median 'g' value (E_g) for imputation: 3.0093e+00
# Pre-processing finished in 0.00 seconds.
# [2026/02/06 19:28:47] Running TeraFlux optimization...
# Creating stoichiometric constraints...
# Adding known flux constraints...
# Solving with standard FBA to get an initial guess (x0)...
# Adding known flux constraints...
# R_EX_glc__D_e -9.878744309604478
# {'R_EX_glc__D_e': 9.878744309604478, 'R_EX_nh4_e': inf, 'R_EX_o2_e': inf, 'R_EX_pi_e': inf}
# FBA solution found. Objective value: 0.9055. Status: optimal
# ## Solving the non-linear optimization problem with IPOPT...
# Solver finished. Status: Solve_Succeeded | Success: True
# Optimization took: 0.03 s
# [2026/02/06 19:28:47] Saving results...
# [2026/02/06 19:28:47] Ecoli_core - glucose_iter_6 processed.
# ================================================================================
#
# ==================== STARTING: Ecoli_core - glucose_iter_7 =====================
# [2026/02/06 19:28:47] Loading metabolic model: ecoli_core.xml
# [2026/02/06 19:28:47] Loading transcriptomic data: transcriptome_7.csv
# [2026/02/06 19:28:47] Loading known fluxes: knownFluxes_7.csv
# [2026/02/06 19:28:47] Updating model (bounds, medium)...
# Applying medium from: medium.csv
# Starting data pre-processing...
# Capping FPKM values at 95th percentile: 56.6138
# Median 'g' value (E_g) for imputation: 4.0002e+00
# Pre-processing finished in 0.00 seconds.
# [2026/02/06 19:28:47] Running TeraFlux optimization...
# Creating stoichiometric constraints...
# Adding known flux constraints...
# Solving with standard FBA to get an initial guess (x0)...
# Adding known flux constraints...
# R_EX_glc__D_e -9.86722171249735
# {'R_EX_glc__D_e': 9.86722171249735, 'R_EX_nh4_e': inf, 'R_EX_o2_e': inf, 'R_EX_pi_e': inf}
# FBA solution found. Objective value: 0.9045. Status: optimal
# ## Solving the non-linear optimization problem with IPOPT...
# Solver finished. Status: Solve_Succeeded | Success: True
# Optimization took: 0.04 s
# [2026/02/06 19:28:48] Saving results...
# [2026/02/06 19:28:48] Ecoli_core - glucose_iter_7 processed.
# ================================================================================
#
# ==================== STARTING: Ecoli_core - glucose_iter_8 =====================
# [2026/02/06 19:28:48] Loading metabolic model: ecoli_core.xml
# [2026/02/06 19:28:48] Loading transcriptomic data: transcriptome_8.csv
# [2026/02/06 19:28:48] Loading known fluxes: knownFluxes_8.csv
# [2026/02/06 19:28:48] Updating model (bounds, medium)...
# Applying medium from: medium.csv
# Starting data pre-processing...
# Capping FPKM values at 95th percentile: 72.0767
# Median 'g' value (E_g) for imputation: 5.0215e+00
# Pre-processing finished in 0.00 seconds.
# [2026/02/06 19:28:48] Running TeraFlux optimization...
# Creating stoichiometric constraints...
# Adding known flux constraints...
# Solving with standard FBA to get an initial guess (x0)...
# Adding known flux constraints...
# R_EX_glc__D_e -9.928097908877
# {'R_EX_glc__D_e': 9.928097908877, 'R_EX_nh4_e': inf, 'R_EX_o2_e': inf, 'R_EX_pi_e': inf}
# FBA solution found. Objective value: 0.9101. Status: optimal
# ## Solving the non-linear optimization problem with IPOPT...
# Solver finished. Status: Solve_Succeeded | Success: True
# Optimization took: 0.03 s
# [2026/02/06 19:28:48] Saving results...
# [2026/02/06 19:28:48] Ecoli_core - glucose_iter_8 processed.
# ================================================================================
#
# ==================== STARTING: Ecoli_core - glucose_iter_9 =====================
# [2026/02/06 19:28:48] Loading metabolic model: ecoli_core.xml
# [2026/02/06 19:28:48] Loading transcriptomic data: transcriptome_9.csv
# [2026/02/06 19:28:48] Loading known fluxes: knownFluxes_9.csv
# [2026/02/06 19:28:48] Updating model (bounds, medium)...
# Applying medium from: medium.csv
# Starting data pre-processing...
# Capping FPKM values at 95th percentile: 68.6970
# Median 'g' value (E_g) for imputation: 4.1069e+00
# Pre-processing finished in 0.00 seconds.
# [2026/02/06 19:28:48] Running TeraFlux optimization...
# Creating stoichiometric constraints...
# Adding known flux constraints...
# Solving with standard FBA to get an initial guess (x0)...
# Adding known flux constraints...
# R_EX_glc__D_e -9.819050530819352
# {'R_EX_glc__D_e': 9.819050530819352, 'R_EX_nh4_e': inf, 'R_EX_o2_e': inf, 'R_EX_pi_e': inf}
# FBA solution found. Objective value: 0.9001. Status: optimal
# ## Solving the non-linear optimization problem with IPOPT...
# Solver finished. Status: Solve_Succeeded | Success: True
# Optimization took: 0.03 s
# [2026/02/06 19:28:48] Saving results...
# [2026/02/06 19:28:48] Ecoli_core - glucose_iter_9 processed.
# ================================================================================
#
# ==================== STARTING: Ecoli_core - glucose_iter_10 ====================
# [2026/02/06 19:28:48] Loading metabolic model: ecoli_core.xml
# [2026/02/06 19:28:48] Loading transcriptomic data: transcriptome_10.csv
# [2026/02/06 19:28:48] Loading known fluxes: knownFluxes_10.csv
# [2026/02/06 19:28:48] Updating model (bounds, medium)...
# Applying medium from: medium.csv
# Starting data pre-processing...
# Capping FPKM values at 95th percentile: 45.6648
# Median 'g' value (E_g) for imputation: 2.6380e+00
# Pre-processing finished in 0.00 seconds.
# [2026/02/06 19:28:48] Running TeraFlux optimization...
# Creating stoichiometric constraints...
# Adding known flux constraints...
# Solving with standard FBA to get an initial guess (x0)...
# Adding known flux constraints...
# R_EX_glc__D_e -9.590408382915427
# {'R_EX_glc__D_e': 9.590408382915427, 'R_EX_nh4_e': inf, 'R_EX_o2_e': inf, 'R_EX_pi_e': inf}
# FBA solution found. Objective value: 0.8791. Status: optimal
# ## Solving the non-linear optimization problem with IPOPT...
# Solver finished. Status: Solve_Succeeded | Success: True
# Optimization took: 0.03 s
# [2026/02/06 19:28:48] Saving results...
# [2026/02/06 19:28:48] Ecoli_core - glucose_iter_10 processed.
# ================================================================================
#
# ==================== STARTING: Ecoli_core - glucose_iter_11 ====================
# [2026/02/06 19:28:48] Loading metabolic model: ecoli_core.xml
# [2026/02/06 19:28:49] Loading transcriptomic data: transcriptome_11.csv
# [2026/02/06 19:28:49] Loading known fluxes: knownFluxes_11.csv
# [2026/02/06 19:28:49] Updating model (bounds, medium)...
# Applying medium from: medium.csv
# Starting data pre-processing...
# Capping FPKM values at 95th percentile: 23.9172
# Median 'g' value (E_g) for imputation: 2.7930e+00
# Pre-processing finished in 0.00 seconds.
# [2026/02/06 19:28:49] Running TeraFlux optimization...
# Creating stoichiometric constraints...
# Adding known flux constraints...
# Solving with standard FBA to get an initial guess (x0)...
# Adding known flux constraints...
# R_EX_glc__D_e -9.532198735362574
# {'R_EX_glc__D_e': 9.532198735362574, 'R_EX_nh4_e': inf, 'R_EX_o2_e': inf, 'R_EX_pi_e': inf}
# FBA solution found. Objective value: 0.8738. Status: optimal
# ## Solving the non-linear optimization problem with IPOPT...
# Solver finished. Status: Solve_Succeeded | Success: True
# Optimization took: 0.03 s
# [2026/02/06 19:28:49] Saving results...
# [2026/02/06 19:28:49] Ecoli_core - glucose_iter_11 processed.
# ================================================================================
#
# ==================== STARTING: Ecoli_core - glucose_iter_12 ====================
# [2026/02/06 19:28:49] Loading metabolic model: ecoli_core.xml
# [2026/02/06 19:28:49] Loading transcriptomic data: transcriptome_12.csv
# [2026/02/06 19:28:49] Loading known fluxes: knownFluxes_12.csv
# [2026/02/06 19:28:49] Updating model (bounds, medium)...
# Applying medium from: medium.csv
# Starting data pre-processing...
# Capping FPKM values at 95th percentile: 40.9474
# Median 'g' value (E_g) for imputation: 4.2302e+00
# Pre-processing finished in 0.00 seconds.
# [2026/02/06 19:28:49] Running TeraFlux optimization...
# Creating stoichiometric constraints...
# Adding known flux constraints...
# Solving with standard FBA to get an initial guess (x0)...
# Adding known flux constraints...
# R_EX_glc__D_e -9.31753152754256
# {'R_EX_glc__D_e': 9.31753152754256, 'R_EX_nh4_e': inf, 'R_EX_o2_e': inf, 'R_EX_pi_e': inf}
# FBA solution found. Objective value: 0.8541. Status: optimal
# ## Solving the non-linear optimization problem with IPOPT...
# Solver finished. Status: Solve_Succeeded | Success: True
# Optimization took: 0.03 s
# [2026/02/06 19:28:49] Saving results...
# [2026/02/06 19:28:49] Ecoli_core - glucose_iter_12 processed.
# ================================================================================
#
# ==================== STARTING: Ecoli_core - glucose_iter_13 ====================
# [2026/02/06 19:28:49] Loading metabolic model: ecoli_core.xml
# [2026/02/06 19:28:49] Loading transcriptomic data: transcriptome_13.csv
# [2026/02/06 19:28:49] Loading known fluxes: knownFluxes_13.csv
# [2026/02/06 19:28:49] Updating model (bounds, medium)...
# Applying medium from: medium.csv
# Starting data pre-processing...
# Capping FPKM values at 95th percentile: 40.7050
# Median 'g' value (E_g) for imputation: 2.3124e+00
# Pre-processing finished in 0.00 seconds.
# [2026/02/06 19:28:49] Running TeraFlux optimization...
# Creating stoichiometric constraints...
# Adding known flux constraints...
# Solving with standard FBA to get an initial guess (x0)...
# Adding known flux constraints...
# R_EX_glc__D_e -9.750710845986152
# {'R_EX_glc__D_e': 9.750710845986152, 'R_EX_nh4_e': inf, 'R_EX_o2_e': inf, 'R_EX_pi_e': inf}
# FBA solution found. Objective value: 0.8938. Status: optimal
# ## Solving the non-linear optimization problem with IPOPT...
# Solver finished. Status: Solve_Succeeded | Success: True
# Optimization took: 0.03 s
# [2026/02/06 19:28:49] Saving results...
# [2026/02/06 19:28:49] Ecoli_core - glucose_iter_13 processed.
# ================================================================================
#
# ==================== STARTING: Ecoli_core - glucose_iter_14 ====================
# [2026/02/06 19:28:49] Loading metabolic model: ecoli_core.xml
# [2026/02/06 19:28:49] Loading transcriptomic data: transcriptome_14.csv
# [2026/02/06 19:28:49] Loading known fluxes: knownFluxes_14.csv
# [2026/02/06 19:28:49] Updating model (bounds, medium)...
# Applying medium from: medium.csv
# Starting data pre-processing...
# Capping FPKM values at 95th percentile: 41.7450
# Median 'g' value (E_g) for imputation: 6.0496e+00
# Pre-processing finished in 0.00 seconds.
# [2026/02/06 19:28:50] Running TeraFlux optimization...
# Creating stoichiometric constraints...
# Adding known flux constraints...
# Solving with standard FBA to get an initial guess (x0)...
# Adding known flux constraints...
# R_EX_glc__D_e -9.38728565201126
# {'R_EX_glc__D_e': 9.38728565201126, 'R_EX_nh4_e': inf, 'R_EX_o2_e': inf, 'R_EX_pi_e': inf}
# FBA solution found. Objective value: 0.8605. Status: optimal
# ## Solving the non-linear optimization problem with IPOPT...
# Solver finished. Status: Solve_Succeeded | Success: True
# Optimization took: 0.03 s
# [2026/02/06 19:28:50] Saving results...
# [2026/02/06 19:28:50] Ecoli_core - glucose_iter_14 processed.
# ================================================================================
#
# ==================== STARTING: Ecoli_core - glucose_iter_15 ====================
# [2026/02/06 19:28:50] Loading metabolic model: ecoli_core.xml
# [2026/02/06 19:28:50] Loading transcriptomic data: transcriptome_15.csv
# [2026/02/06 19:28:50] Loading known fluxes: knownFluxes_15.csv
# [2026/02/06 19:28:50] Updating model (bounds, medium)...
# Applying medium from: medium.csv
# Starting data pre-processing...
# Capping FPKM values at 95th percentile: 45.9938
# Median 'g' value (E_g) for imputation: 3.4110e+00
# Pre-processing finished in 0.00 seconds.
# [2026/02/06 19:28:50] Running TeraFlux optimization...
# Creating stoichiometric constraints...
# Adding known flux constraints...
# Solving with standard FBA to get an initial guess (x0)...
# Adding known flux constraints...
# R_EX_glc__D_e -9.218048709282844
# {'R_EX_glc__D_e': 9.218048709282844, 'R_EX_nh4_e': inf, 'R_EX_o2_e': inf, 'R_EX_pi_e': inf}
# FBA solution found. Objective value: 0.8450. Status: optimal
# ## Solving the non-linear optimization problem with IPOPT...
# Solver finished. Status: Solve_Succeeded | Success: True
# Optimization took: 0.04 s
# [2026/02/06 19:28:50] Saving results...
# [2026/02/06 19:28:50] Ecoli_core - glucose_iter_15 processed.
# ================================================================================
#
# ==================== STARTING: Ecoli_core - glucose_iter_16 ====================
# [2026/02/06 19:28:50] Loading metabolic model: ecoli_core.xml
# [2026/02/06 19:28:50] Loading transcriptomic data: transcriptome_16.csv
# [2026/02/06 19:28:50] Loading known fluxes: knownFluxes_16.csv
# [2026/02/06 19:28:50] Updating model (bounds, medium)...
# Applying medium from: medium.csv
# Starting data pre-processing...
# Capping FPKM values at 95th percentile: 35.2529
# Median 'g' value (E_g) for imputation: 3.1078e+00
# Pre-processing finished in 0.00 seconds.
# [2026/02/06 19:28:50] Running TeraFlux optimization...
# Creating stoichiometric constraints...
# Adding known flux constraints...
# Solving with standard FBA to get an initial guess (x0)...
# Adding known flux constraints...
# R_EX_glc__D_e -8.42657533957641
# {'R_EX_glc__D_e': 8.42657533957641, 'R_EX_nh4_e': inf, 'R_EX_o2_e': inf, 'R_EX_pi_e': inf}
# FBA solution found. Objective value: 0.7724. Status: optimal
# ## Solving the non-linear optimization problem with IPOPT...
# Solver finished. Status: Solve_Succeeded | Success: True
# Optimization took: 0.03 s
# [2026/02/06 19:28:50] Saving results...
# [2026/02/06 19:28:50] Ecoli_core - glucose_iter_16 processed.
# ================================================================================
#
# ==================== STARTING: Ecoli_core - glucose_iter_17 ====================
# [2026/02/06 19:28:50] Loading metabolic model: ecoli_core.xml
# [2026/02/06 19:28:50] Loading transcriptomic data: transcriptome_17.csv
# [2026/02/06 19:28:50] Loading known fluxes: knownFluxes_17.csv
# [2026/02/06 19:28:50] Updating model (bounds, medium)...
# Applying medium from: medium.csv
# Starting data pre-processing...
# Capping FPKM values at 95th percentile: 41.1287
# Median 'g' value (E_g) for imputation: 4.1416e+00
# Pre-processing finished in 0.00 seconds.
# [2026/02/06 19:28:50] Running TeraFlux optimization...
# Creating stoichiometric constraints...
# Adding known flux constraints...
# Solving with standard FBA to get an initial guess (x0)...
# Adding known flux constraints...
# R_EX_glc__D_e -9.831379369846635
# {'R_EX_glc__D_e': 9.831379369846635, 'R_EX_nh4_e': inf, 'R_EX_o2_e': inf, 'R_EX_pi_e': inf}
# FBA solution found. Objective value: 0.9012. Status: optimal
# ## Solving the non-linear optimization problem with IPOPT...
# Solver finished. Status: Solve_Succeeded | Success: True
# Optimization took: 0.04 s
# [2026/02/06 19:28:50] Saving results...
# [2026/02/06 19:28:50] Ecoli_core - glucose_iter_17 processed.
# ================================================================================
#
# ==================== STARTING: Ecoli_core - glucose_iter_18 ====================
# [2026/02/06 19:28:50] Loading metabolic model: ecoli_core.xml
# [2026/02/06 19:28:51] Loading transcriptomic data: transcriptome_18.csv
# [2026/02/06 19:28:51] Loading known fluxes: knownFluxes_18.csv
# [2026/02/06 19:28:51] Updating model (bounds, medium)...
# Applying medium from: medium.csv
# Starting data pre-processing...
# Capping FPKM values at 95th percentile: 47.9231
# Median 'g' value (E_g) for imputation: 3.7950e+00
# Pre-processing finished in 0.00 seconds.
# [2026/02/06 19:28:51] Running TeraFlux optimization...
# Creating stoichiometric constraints...
# Adding known flux constraints...
# Solving with standard FBA to get an initial guess (x0)...
# Adding known flux constraints...
# R_EX_glc__D_e -9.794400622365597
# {'R_EX_glc__D_e': 9.794400622365597, 'R_EX_nh4_e': inf, 'R_EX_o2_e': inf, 'R_EX_pi_e': inf}
# FBA solution found. Objective value: 0.8978. Status: optimal
# ## Solving the non-linear optimization problem with IPOPT...
# Solver finished. Status: Solve_Succeeded | Success: True
# Optimization took: 0.03 s
# [2026/02/06 19:28:51] Saving results...
# [2026/02/06 19:28:51] Ecoli_core - glucose_iter_18 processed.
# ================================================================================
#
# ==================== STARTING: Ecoli_core - glucose_iter_19 ====================
# [2026/02/06 19:28:51] Loading metabolic model: ecoli_core.xml
# [2026/02/06 19:28:51] Loading transcriptomic data: transcriptome_19.csv
# [2026/02/06 19:28:51] Loading known fluxes: knownFluxes_19.csv
# [2026/02/06 19:28:51] Updating model (bounds, medium)...
# Applying medium from: medium.csv
# Starting data pre-processing...
# Capping FPKM values at 95th percentile: 38.4637
# Median 'g' value (E_g) for imputation: 4.0861e+00
# Pre-processing finished in 0.00 seconds.
# [2026/02/06 19:28:51] Running TeraFlux optimization...
# Creating stoichiometric constraints...
# Adding known flux constraints...
# Solving with standard FBA to get an initial guess (x0)...
# Adding known flux constraints...
# R_EX_glc__D_e -9.918816231078807
# {'R_EX_glc__D_e': 9.918816231078807, 'R_EX_nh4_e': inf, 'R_EX_o2_e': inf, 'R_EX_pi_e': inf}
# FBA solution found. Objective value: 0.9092. Status: optimal
# ## Solving the non-linear optimization problem with IPOPT...
# Solver finished. Status: Solve_Succeeded | Success: True
# Optimization took: 0.03 s
# [2026/02/06 19:28:51] Saving results...
# [2026/02/06 19:28:51] Ecoli_core - glucose_iter_19 processed.
# ================================================================================
#
# ==================== STARTING: Ecoli_core - glucose_iter_20 ====================
# [2026/02/06 19:28:51] Loading metabolic model: ecoli_core.xml
# [2026/02/06 19:28:51] Loading transcriptomic data: transcriptome_20.csv
# [2026/02/06 19:28:51] Loading known fluxes: knownFluxes_20.csv
# [2026/02/06 19:28:51] Updating model (bounds, medium)...
# Applying medium from: medium.csv
# Starting data pre-processing...
# Capping FPKM values at 95th percentile: 54.1815
# Median 'g' value (E_g) for imputation: 3.4810e+00
# Pre-processing finished in 0.00 seconds.
# [2026/02/06 19:28:51] Running TeraFlux optimization...
# Creating stoichiometric constraints...
# Adding known flux constraints...
# Solving with standard FBA to get an initial guess (x0)...
# Adding known flux constraints...
# R_EX_glc__D_e -9.960296571625747
# {'R_EX_glc__D_e': 9.960296571625747, 'R_EX_nh4_e': inf, 'R_EX_o2_e': inf, 'R_EX_pi_e': inf}
# FBA solution found. Objective value: 0.9130. Status: optimal
# ## Solving the non-linear optimization problem with IPOPT...
# Solver finished. Status: Solve_Succeeded | Success: True
# Optimization took: 0.04 s
# [2026/02/06 19:28:51] Saving results...
# [2026/02/06 19:28:51] Ecoli_core - glucose_iter_20 processed.
# ================================================================================
#
# ==================== STARTING: Ecoli_core - glucose_iter_21 ====================
# [2026/02/06 19:28:51] Loading metabolic model: ecoli_core.xml
# [2026/02/06 19:28:51] Loading transcriptomic data: transcriptome_21.csv
# [2026/02/06 19:28:51] Loading known fluxes: knownFluxes_21.csv
# [2026/02/06 19:28:51] Updating model (bounds, medium)...
# Applying medium from: medium.csv
# Starting data pre-processing...
# Capping FPKM values at 95th percentile: 53.0911
# Median 'g' value (E_g) for imputation: 3.5638e+00
# Pre-processing finished in 0.00 seconds.
# [2026/02/06 19:28:52] Running TeraFlux optimization...
# Creating stoichiometric constraints...
# Adding known flux constraints...
# Solving with standard FBA to get an initial guess (x0)...
# Adding known flux constraints...
# R_EX_glc__D_e -9.773653037538985
# {'R_EX_glc__D_e': 9.773653037538985, 'R_EX_nh4_e': inf, 'R_EX_o2_e': inf, 'R_EX_pi_e': inf}
# FBA solution found. Objective value: 0.8959. Status: optimal
# ## Solving the non-linear optimization problem with IPOPT...
# Solver finished. Status: Solve_Succeeded | Success: True
# Optimization took: 0.03 s
# [2026/02/06 19:28:52] Saving results...
# [2026/02/06 19:28:52] Ecoli_core - glucose_iter_21 processed.
# ================================================================================
#
# ==================== STARTING: Ecoli_core - glucose_iter_22 ====================
# [2026/02/06 19:28:52] Loading metabolic model: ecoli_core.xml
# [2026/02/06 19:28:52] Loading transcriptomic data: transcriptome_22.csv
# [2026/02/06 19:28:52] Loading known fluxes: knownFluxes_22.csv
# [2026/02/06 19:28:52] Updating model (bounds, medium)...
# Applying medium from: medium.csv
# Starting data pre-processing...
# Capping FPKM values at 95th percentile: 23.4728
# Median 'g' value (E_g) for imputation: 3.1684e+00
# Pre-processing finished in 0.00 seconds.
# [2026/02/06 19:28:52] Running TeraFlux optimization...
# Creating stoichiometric constraints...
# Adding known flux constraints...
# Solving with standard FBA to get an initial guess (x0)...
# Adding known flux constraints...
# R_EX_glc__D_e -9.660998108529222
# {'R_EX_glc__D_e': 9.660998108529222, 'R_EX_nh4_e': inf, 'R_EX_o2_e': inf, 'R_EX_pi_e': inf}
# FBA solution found. Objective value: 0.8856. Status: optimal
# ## Solving the non-linear optimization problem with IPOPT...
# Solver finished. Status: Solve_Succeeded | Success: True
# Optimization took: 0.03 s
# [2026/02/06 19:28:52] Saving results...
# [2026/02/06 19:28:52] Ecoli_core - glucose_iter_22 processed.
# ================================================================================
#
# ==================== STARTING: Ecoli_core - glucose_iter_23 ====================
# [2026/02/06 19:28:52] Loading metabolic model: ecoli_core.xml
# [2026/02/06 19:28:52] Loading transcriptomic data: transcriptome_23.csv
# [2026/02/06 19:28:52] Loading known fluxes: knownFluxes_23.csv
# [2026/02/06 19:28:52] Updating model (bounds, medium)...
# Applying medium from: medium.csv
# Starting data pre-processing...
# Capping FPKM values at 95th percentile: 36.7450
# Median 'g' value (E_g) for imputation: 2.2047e+00
# Pre-processing finished in 0.00 seconds.
# [2026/02/06 19:28:52] Running TeraFlux optimization...
# Creating stoichiometric constraints...
# Adding known flux constraints...
# Solving with standard FBA to get an initial guess (x0)...
# Adding known flux constraints...
# R_EX_glc__D_e -9.218887501886364
# {'R_EX_glc__D_e': 9.218887501886364, 'R_EX_nh4_e': inf, 'R_EX_o2_e': inf, 'R_EX_pi_e': inf}
# FBA solution found. Objective value: 0.8450. Status: optimal
# ## Solving the non-linear optimization problem with IPOPT...
# Solver finished. Status: Solve_Succeeded | Success: True
# Optimization took: 0.03 s
# [2026/02/06 19:28:52] Saving results...
# [2026/02/06 19:28:52] Ecoli_core - glucose_iter_23 processed.
# ================================================================================
#
# ==================== STARTING: Ecoli_core - glucose_iter_24 ====================
# [2026/02/06 19:28:52] Loading metabolic model: ecoli_core.xml
# [2026/02/06 19:28:52] Loading transcriptomic data: transcriptome_24.csv
# [2026/02/06 19:28:52] Loading known fluxes: knownFluxes_24.csv
# [2026/02/06 19:28:52] Updating model (bounds, medium)...
# Applying medium from: medium.csv
# Starting data pre-processing...
# Capping FPKM values at 95th percentile: 28.3510
# Median 'g' value (E_g) for imputation: 3.9705e+00
# Pre-processing finished in 0.00 seconds.
# [2026/02/06 19:28:52] Running TeraFlux optimization...
# Creating stoichiometric constraints...
# Adding known flux constraints...
# Solving with standard FBA to get an initial guess (x0)...
# Adding known flux constraints...
# R_EX_glc__D_e -9.938634297883365
# {'R_EX_glc__D_e': 9.938634297883365, 'R_EX_nh4_e': inf, 'R_EX_o2_e': inf, 'R_EX_pi_e': inf}
# FBA solution found. Objective value: 0.9110. Status: optimal
# ## Solving the non-linear optimization problem with IPOPT...
# Solver finished. Status: Solve_Succeeded | Success: True
# Optimization took: 0.04 s
# [2026/02/06 19:28:53] Saving results...
# [2026/02/06 19:28:53] Ecoli_core - glucose_iter_24 processed.
# ================================================================================
#
# ==================== STARTING: Ecoli_core - glucose_iter_25 ====================
# [2026/02/06 19:28:53] Loading metabolic model: ecoli_core.xml
# [2026/02/06 19:28:53] Loading transcriptomic data: transcriptome_25.csv
# [2026/02/06 19:28:53] Loading known fluxes: knownFluxes_25.csv
# [2026/02/06 19:28:53] Updating model (bounds, medium)...
# Applying medium from: medium.csv
# Starting data pre-processing...
# Capping FPKM values at 95th percentile: 32.7309
# Median 'g' value (E_g) for imputation: 3.8690e+00
# Pre-processing finished in 0.00 seconds.
# [2026/02/06 19:28:53] Running TeraFlux optimization...
# Creating stoichiometric constraints...
# Adding known flux constraints...
# Solving with standard FBA to get an initial guess (x0)...
# Adding known flux constraints...
# R_EX_glc__D_e -9.652195984891703
# {'R_EX_glc__D_e': 9.652195984891703, 'R_EX_nh4_e': inf, 'R_EX_o2_e': inf, 'R_EX_pi_e': inf}
# FBA solution found. Objective value: 0.8848. Status: optimal
# ## Solving the non-linear optimization problem with IPOPT...
# Solver finished. Status: Solve_Succeeded | Success: True
# Optimization took: 0.03 s
# [2026/02/06 19:28:53] Saving results...
# [2026/02/06 19:28:53] Ecoli_core - glucose_iter_25 processed.
# ================================================================================
#
# ==================== STARTING: Ecoli_core - glucose_iter_26 ====================
# [2026/02/06 19:28:53] Loading metabolic model: ecoli_core.xml
# [2026/02/06 19:28:53] Loading transcriptomic data: transcriptome_26.csv
# [2026/02/06 19:28:53] Loading known fluxes: knownFluxes_26.csv
# [2026/02/06 19:28:53] Updating model (bounds, medium)...
# Applying medium from: medium.csv
# Starting data pre-processing...
# Capping FPKM values at 95th percentile: 49.5329
# Median 'g' value (E_g) for imputation: 4.8273e+00
# Pre-processing finished in 0.00 seconds.
# [2026/02/06 19:28:53] Running TeraFlux optimization...
# Creating stoichiometric constraints...
# Adding known flux constraints...
# Solving with standard FBA to get an initial guess (x0)...
# Adding known flux constraints...
# R_EX_glc__D_e -9.891009627807202
# {'R_EX_glc__D_e': 9.891009627807202, 'R_EX_nh4_e': inf, 'R_EX_o2_e': inf, 'R_EX_pi_e': inf}
# FBA solution found. Objective value: 0.9067. Status: optimal
# ## Solving the non-linear optimization problem with IPOPT...
# Solver finished. Status: Solve_Succeeded | Success: True
# Optimization took: 0.03 s
# [2026/02/06 19:28:53] Saving results...
# [2026/02/06 19:28:53] Ecoli_core - glucose_iter_26 processed.
# ================================================================================
#
# ==================== STARTING: Ecoli_core - glucose_iter_27 ====================
# [2026/02/06 19:28:53] Loading metabolic model: ecoli_core.xml
# [2026/02/06 19:28:53] Loading transcriptomic data: transcriptome_27.csv
# [2026/02/06 19:28:53] Loading known fluxes: knownFluxes_27.csv
# [2026/02/06 19:28:53] Updating model (bounds, medium)...
# Applying medium from: medium.csv
# Starting data pre-processing...
# Capping FPKM values at 95th percentile: 36.7483
# Median 'g' value (E_g) for imputation: 3.1943e+00
# Pre-processing finished in 0.00 seconds.
# [2026/02/06 19:28:53] Running TeraFlux optimization...
# Creating stoichiometric constraints...
# Adding known flux constraints...
# Solving with standard FBA to get an initial guess (x0)...
# Adding known flux constraints...
# R_EX_glc__D_e -9.649676278172311
# {'R_EX_glc__D_e': 9.649676278172311, 'R_EX_nh4_e': inf, 'R_EX_o2_e': inf, 'R_EX_pi_e': inf}
# FBA solution found. Objective value: 0.8845. Status: optimal
# ## Solving the non-linear optimization problem with IPOPT...
# Solver finished. Status: Solve_Succeeded | Success: True
# Optimization took: 0.03 s
# [2026/02/06 19:28:53] Saving results...
# [2026/02/06 19:28:53] Ecoli_core - glucose_iter_27 processed.
# ================================================================================
#
# ==================== STARTING: Ecoli_core - glucose_iter_28 ====================
# [2026/02/06 19:28:53] Loading metabolic model: ecoli_core.xml
# [2026/02/06 19:28:53] Loading transcriptomic data: transcriptome_28.csv
# [2026/02/06 19:28:53] Loading known fluxes: knownFluxes_28.csv
# [2026/02/06 19:28:53] Updating model (bounds, medium)...
# Applying medium from: medium.csv
# Starting data pre-processing...
# Capping FPKM values at 95th percentile: 28.4765
# Median 'g' value (E_g) for imputation: 3.4003e+00
# Pre-processing finished in 0.00 seconds.
# [2026/02/06 19:28:54] Running TeraFlux optimization...
# Creating stoichiometric constraints...
# Adding known flux constraints...
# Solving with standard FBA to get an initial guess (x0)...
# Adding known flux constraints...
# R_EX_glc__D_e -9.90383396187549
# {'R_EX_glc__D_e': 9.90383396187549, 'R_EX_nh4_e': inf, 'R_EX_o2_e': inf, 'R_EX_pi_e': inf}
# FBA solution found. Objective value: 0.9078. Status: optimal
# ## Solving the non-linear optimization problem with IPOPT...
# Solver finished. Status: Solve_Succeeded | Success: True
# Optimization took: 0.03 s
# [2026/02/06 19:28:54] Saving results...
# [2026/02/06 19:28:54] Ecoli_core - glucose_iter_28 processed.
# ================================================================================
#
# ==================== STARTING: Ecoli_core - glucose_iter_29 ====================
# [2026/02/06 19:28:54] Loading metabolic model: ecoli_core.xml
# [2026/02/06 19:28:54] Loading transcriptomic data: transcriptome_29.csv
# [2026/02/06 19:28:54] Loading known fluxes: knownFluxes_29.csv
# [2026/02/06 19:28:54] Updating model (bounds, medium)...
# Applying medium from: medium.csv
# Starting data pre-processing...
# Capping FPKM values at 95th percentile: 49.7747
# Median 'g' value (E_g) for imputation: 5.2510e+00
# Pre-processing finished in 0.00 seconds.
# [2026/02/06 19:28:54] Running TeraFlux optimization...
# Creating stoichiometric constraints...
# Adding known flux constraints...
# Solving with standard FBA to get an initial guess (x0)...
# Adding known flux constraints...
# R_EX_glc__D_e -9.862662890950688
# {'R_EX_glc__D_e': 9.862662890950688, 'R_EX_nh4_e': inf, 'R_EX_o2_e': inf, 'R_EX_pi_e': inf}
# FBA solution found. Objective value: 0.9041. Status: optimal
# ## Solving the non-linear optimization problem with IPOPT...
# Solver finished. Status: Solve_Succeeded | Success: True
# Optimization took: 0.03 s
# [2026/02/06 19:28:54] Saving results...
# [2026/02/06 19:28:54] Ecoli_core - glucose_iter_29 processed.
# ================================================================================
#
# ==================== STARTING: Ecoli_core - glucose_iter_30 ====================
# [2026/02/06 19:28:54] Loading metabolic model: ecoli_core.xml
# [2026/02/06 19:28:54] Loading transcriptomic data: transcriptome_30.csv
# [2026/02/06 19:28:54] Loading known fluxes: knownFluxes_30.csv
# [2026/02/06 19:28:54] Updating model (bounds, medium)...
# Applying medium from: medium.csv
# Starting data pre-processing...
# Capping FPKM values at 95th percentile: 24.3467
# Median 'g' value (E_g) for imputation: 2.1012e+00
# Pre-processing finished in 0.00 seconds.
# [2026/02/06 19:28:54] Running TeraFlux optimization...
# Creating stoichiometric constraints...
# Adding known flux constraints...
# Solving with standard FBA to get an initial guess (x0)...
# Adding known flux constraints...
# R_EX_glc__D_e -9.353292157671884
# {'R_EX_glc__D_e': 9.353292157671884, 'R_EX_nh4_e': inf, 'R_EX_o2_e': inf, 'R_EX_pi_e': inf}
# FBA solution found. Objective value: 0.8574. Status: optimal
# ## Solving the non-linear optimization problem with IPOPT...
# Solver finished. Status: Solve_Succeeded | Success: True
# Optimization took: 0.04 s
# [2026/02/06 19:28:54] Saving results...
# [2026/02/06 19:28:54] Ecoli_core - glucose_iter_30 processed.
# ================================================================================
#
# ==================== STARTING: Ecoli_core - glucose_iter_31 ====================
# [2026/02/06 19:28:54] Loading metabolic model: ecoli_core.xml
# [2026/02/06 19:28:54] Loading transcriptomic data: transcriptome_31.csv
# [2026/02/06 19:28:54] Loading known fluxes: knownFluxes_31.csv
# [2026/02/06 19:28:54] Updating model (bounds, medium)...
# Applying medium from: medium.csv
# Starting data pre-processing...
# Capping FPKM values at 95th percentile: 42.7021
# Median 'g' value (E_g) for imputation: 4.5565e+00
# Pre-processing finished in 0.00 seconds.
# [2026/02/06 19:28:54] Running TeraFlux optimization...
# Creating stoichiometric constraints...
# Adding known flux constraints...
# Solving with standard FBA to get an initial guess (x0)...
# Adding known flux constraints...
# R_EX_glc__D_e -9.211036037064888
# {'R_EX_glc__D_e': 9.211036037064888, 'R_EX_nh4_e': inf, 'R_EX_o2_e': inf, 'R_EX_pi_e': inf}
# FBA solution found. Objective value: 0.8443. Status: optimal
# ## Solving the non-linear optimization problem with IPOPT...
# Solver finished. Status: Solve_Succeeded | Success: True
# Optimization took: 0.03 s
# [2026/02/06 19:28:55] Saving results...
# [2026/02/06 19:28:55] Ecoli_core - glucose_iter_31 processed.
# ================================================================================
#
# ==================== STARTING: Ecoli_core - glucose_iter_32 ====================
# [2026/02/06 19:28:55] Loading metabolic model: ecoli_core.xml
# [2026/02/06 19:28:55] Loading transcriptomic data: transcriptome_32.csv
# [2026/02/06 19:28:55] Loading known fluxes: knownFluxes_32.csv
# [2026/02/06 19:28:55] Updating model (bounds, medium)...
# Applying medium from: medium.csv
# Starting data pre-processing...
# Capping FPKM values at 95th percentile: 48.6414
# Median 'g' value (E_g) for imputation: 4.6383e+00
# Pre-processing finished in 0.00 seconds.
# [2026/02/06 19:28:55] Running TeraFlux optimization...
# Creating stoichiometric constraints...
# Adding known flux constraints...
# Solving with standard FBA to get an initial guess (x0)...
# Adding known flux constraints...
# R_EX_glc__D_e -9.876163524111844
# {'R_EX_glc__D_e': 9.876163524111844, 'R_EX_nh4_e': inf, 'R_EX_o2_e': inf, 'R_EX_pi_e': inf}
# FBA solution found. Objective value: 0.9053. Status: optimal
# ## Solving the non-linear optimization problem with IPOPT...
# Solver finished. Status: Solve_Succeeded | Success: True
# Optimization took: 0.04 s
# [2026/02/06 19:28:55] Saving results...
# [2026/02/06 19:28:55] Ecoli_core - glucose_iter_32 processed.
# ================================================================================
#
# ==================== STARTING: Ecoli_core - glucose_iter_33 ====================
# [2026/02/06 19:28:55] Loading metabolic model: ecoli_core.xml
# [2026/02/06 19:28:55] Loading transcriptomic data: transcriptome_33.csv
# [2026/02/06 19:28:55] Loading known fluxes: knownFluxes_33.csv
# [2026/02/06 19:28:55] Updating model (bounds, medium)...
# Applying medium from: medium.csv
# Starting data pre-processing...
# Capping FPKM values at 95th percentile: 52.6763
# Median 'g' value (E_g) for imputation: 6.0474e+00
# Pre-processing finished in 0.00 seconds.
# [2026/02/06 19:28:55] Running TeraFlux optimization...
# Creating stoichiometric constraints...
# Adding known flux constraints...
# Solving with standard FBA to get an initial guess (x0)...
# Adding known flux constraints...
# R_EX_glc__D_e -9.869069835765789
# {'R_EX_glc__D_e': 9.869069835765789, 'R_EX_nh4_e': inf, 'R_EX_o2_e': inf, 'R_EX_pi_e': inf}
# FBA solution found. Objective value: 0.9046. Status: optimal
# ## Solving the non-linear optimization problem with IPOPT...
# Solver finished. Status: Solve_Succeeded | Success: True
# Optimization took: 0.03 s
# [2026/02/06 19:28:55] Saving results...
# [2026/02/06 19:28:55] Ecoli_core - glucose_iter_33 processed.
# ================================================================================
#
# ==================== STARTING: Ecoli_core - glucose_iter_34 ====================
# [2026/02/06 19:28:55] Loading metabolic model: ecoli_core.xml
# [2026/02/06 19:28:55] Loading transcriptomic data: transcriptome_34.csv
# [2026/02/06 19:28:55] Loading known fluxes: knownFluxes_34.csv
# [2026/02/06 19:28:55] Updating model (bounds, medium)...
# Applying medium from: medium.csv
# Starting data pre-processing...
# Capping FPKM values at 95th percentile: 37.6392
# Median 'g' value (E_g) for imputation: 5.2008e+00
# Pre-processing finished in 0.00 seconds.
# [2026/02/06 19:28:55] Running TeraFlux optimization...
# Creating stoichiometric constraints...
# Adding known flux constraints...
# Solving with standard FBA to get an initial guess (x0)...
# Adding known flux constraints...
# R_EX_glc__D_e -9.920523497618593
# {'R_EX_glc__D_e': 9.920523497618593, 'R_EX_nh4_e': inf, 'R_EX_o2_e': inf, 'R_EX_pi_e': inf}
# FBA solution found. Objective value: 0.9094. Status: optimal
# ## Solving the non-linear optimization problem with IPOPT...
# Solver finished. Status: Solve_Succeeded | Success: True
# Optimization took: 0.03 s
# [2026/02/06 19:28:55] Saving results...
# [2026/02/06 19:28:55] Ecoli_core - glucose_iter_34 processed.
# ================================================================================
#
# ==================== STARTING: Ecoli_core - glucose_iter_35 ====================
# [2026/02/06 19:28:55] Loading metabolic model: ecoli_core.xml
# [2026/02/06 19:28:56] Loading transcriptomic data: transcriptome_35.csv
# [2026/02/06 19:28:56] Loading known fluxes: knownFluxes_35.csv
# [2026/02/06 19:28:56] Updating model (bounds, medium)...
# Applying medium from: medium.csv
# Starting data pre-processing...
# Capping FPKM values at 95th percentile: 28.8610
# Median 'g' value (E_g) for imputation: 4.1771e+00
# Pre-processing finished in 0.00 seconds.
# [2026/02/06 19:28:56] Running TeraFlux optimization...
# Creating stoichiometric constraints...
# Adding known flux constraints...
# Solving with standard FBA to get an initial guess (x0)...
# Adding known flux constraints...
# R_EX_glc__D_e -9.901470320959527
# {'R_EX_glc__D_e': 9.901470320959527, 'R_EX_nh4_e': inf, 'R_EX_o2_e': inf, 'R_EX_pi_e': inf}
# FBA solution found. Objective value: 0.9076. Status: optimal
# ## Solving the non-linear optimization problem with IPOPT...
# Solver finished. Status: Solve_Succeeded | Success: True
# Optimization took: 0.04 s
# [2026/02/06 19:28:56] Saving results...
# [2026/02/06 19:28:56] Ecoli_core - glucose_iter_35 processed.
# ================================================================================
#
# ==================== STARTING: Ecoli_core - glucose_iter_36 ====================
# [2026/02/06 19:28:56] Loading metabolic model: ecoli_core.xml
# [2026/02/06 19:28:56] Loading transcriptomic data: transcriptome_36.csv
# [2026/02/06 19:28:56] Loading known fluxes: knownFluxes_36.csv
# [2026/02/06 19:28:56] Updating model (bounds, medium)...
# Applying medium from: medium.csv
# Starting data pre-processing...
# Capping FPKM values at 95th percentile: 51.2855
# Median 'g' value (E_g) for imputation: 4.3273e+00
# Pre-processing finished in 0.00 seconds.
# [2026/02/06 19:28:56] Running TeraFlux optimization...
# Creating stoichiometric constraints...
# Adding known flux constraints...
# Solving with standard FBA to get an initial guess (x0)...
# Adding known flux constraints...
# R_EX_glc__D_e -9.831208529182687
# {'R_EX_glc__D_e': 9.831208529182687, 'R_EX_nh4_e': inf, 'R_EX_o2_e': inf, 'R_EX_pi_e': inf}
# FBA solution found. Objective value: 0.9012. Status: optimal
# ## Solving the non-linear optimization problem with IPOPT...
# Solver finished. Status: Solve_Succeeded | Success: True
# Optimization took: 0.04 s
# [2026/02/06 19:28:56] Saving results...
# [2026/02/06 19:28:56] Ecoli_core - glucose_iter_36 processed.
# ================================================================================
#
# ==================== STARTING: Ecoli_core - glucose_iter_37 ====================
# [2026/02/06 19:28:56] Loading metabolic model: ecoli_core.xml
# [2026/02/06 19:28:56] Loading transcriptomic data: transcriptome_37.csv
# [2026/02/06 19:28:56] Loading known fluxes: knownFluxes_37.csv
# [2026/02/06 19:28:56] Updating model (bounds, medium)...
# Applying medium from: medium.csv
# Starting data pre-processing...
# Capping FPKM values at 95th percentile: 54.7946
# Median 'g' value (E_g) for imputation: 4.8193e+00
# Pre-processing finished in 0.00 seconds.
# [2026/02/06 19:28:56] Running TeraFlux optimization...
# Creating stoichiometric constraints...
# Adding known flux constraints...
# Solving with standard FBA to get an initial guess (x0)...
# Adding known flux constraints...
# R_EX_glc__D_e -9.91895557707354
# {'R_EX_glc__D_e': 9.91895557707354, 'R_EX_nh4_e': inf, 'R_EX_o2_e': inf, 'R_EX_pi_e': inf}
# FBA solution found. Objective value: 0.9092. Status: optimal
# ...
# FBA solution found. Objective value: 0.8777. Status: optimal
# ## Solving the non-linear optimization problem with IPOPT...
# Solver finished. Status: Solve_Succeeded | Success: True
# Optimization took: 0.04 s
# [2026/02/06 19:34:08] Saving results...
# [2026/02/06 19:34:08] Ecoli_core - glucose_iter_987 processed.
# ================================================================================
#
# =================== STARTING: Ecoli_core - glucose_iter_988 ====================
# [2026/02/06 19:34:08] Loading metabolic model: ecoli_core.xml
# [2026/02/06 19:34:08] Loading transcriptomic data: transcriptome_988.csv
# [2026/02/06 19:34:08] Loading known fluxes: knownFluxes_988.csv
# [2026/02/06 19:34:08] Updating model (bounds, medium)...
# Applying medium from: medium.csv
# Starting data pre-processing...
# Capping FPKM values at 95th percentile: 44.3698
# Median 'g' value (E_g) for imputation: 3.1513e+00
# Pre-processing finished in 0.00 seconds.
# [2026/02/06 19:34:08] Running TeraFlux optimization...
# Creating stoichiometric constraints...
# Adding known flux constraints...
# Solving with standard FBA to get an initial guess (x0)...
# Adding known flux constraints...
# R_EX_glc__D_e -9.593043390269392
# {'R_EX_glc__D_e': 9.593043390269392, 'R_EX_nh4_e': inf, 'R_EX_o2_e': inf, 'R_EX_pi_e': inf}
# FBA solution found. Objective value: 0.8793. Status: optimal
# ## Solving the non-linear optimization problem with IPOPT...
# Solver finished. Status: Solve_Succeeded | Success: True
# Optimization took: 0.04 s
# [2026/02/06 19:34:08] Saving results...
# [2026/02/06 19:34:08] Ecoli_core - glucose_iter_988 processed.
# ================================================================================
#
# =================== STARTING: Ecoli_core - glucose_iter_989 ====================
# [2026/02/06 19:34:08] Loading metabolic model: ecoli_core.xml
# [2026/02/06 19:34:08] Loading transcriptomic data: transcriptome_989.csv
# [2026/02/06 19:34:08] Loading known fluxes: knownFluxes_989.csv
# [2026/02/06 19:34:08] Updating model (bounds, medium)...
# Applying medium from: medium.csv
# Starting data pre-processing...
# Capping FPKM values at 95th percentile: 54.5719
# Median 'g' value (E_g) for imputation: 4.2851e+00
# Pre-processing finished in 0.00 seconds.
# [2026/02/06 19:34:09] Running TeraFlux optimization...
# Creating stoichiometric constraints...
# Adding known flux constraints...
# Solving with standard FBA to get an initial guess (x0)...
# Adding known flux constraints...
# R_EX_glc__D_e -9.88717555631662
# {'R_EX_glc__D_e': 9.88717555631662, 'R_EX_nh4_e': inf, 'R_EX_o2_e': inf, 'R_EX_pi_e': inf}
# FBA solution found. Objective value: 0.9063. Status: optimal
# ## Solving the non-linear optimization problem with IPOPT...
# Solver finished. Status: Solve_Succeeded | Success: True
# Optimization took: 0.04 s
# [2026/02/06 19:34:09] Saving results...
# [2026/02/06 19:34:09] Ecoli_core - glucose_iter_989 processed.
# ================================================================================
#
# =================== STARTING: Ecoli_core - glucose_iter_990 ====================
# [2026/02/06 19:34:09] Loading metabolic model: ecoli_core.xml
# [2026/02/06 19:34:09] Loading transcriptomic data: transcriptome_990.csv
# [2026/02/06 19:34:09] Loading known fluxes: knownFluxes_990.csv
# [2026/02/06 19:34:09] Updating model (bounds, medium)...
# Applying medium from: medium.csv
# Starting data pre-processing...
# Capping FPKM values at 95th percentile: 59.3743
# Median 'g' value (E_g) for imputation: 4.1760e+00
# Pre-processing finished in 0.00 seconds.
# [2026/02/06 19:34:09] Running TeraFlux optimization...
# Creating stoichiometric constraints...
# Adding known flux constraints...
# Solving with standard FBA to get an initial guess (x0)...
# Adding known flux constraints...
# R_EX_glc__D_e -9.955322990472036
# {'R_EX_glc__D_e': 9.955322990472036, 'R_EX_nh4_e': inf, 'R_EX_o2_e': inf, 'R_EX_pi_e': inf}
# FBA solution found. Objective value: 0.9126. Status: optimal
# ## Solving the non-linear optimization problem with IPOPT...
# Solver finished. Status: Solve_Succeeded | Success: True
# Optimization took: 0.04 s
# [2026/02/06 19:34:09] Saving results...
# [2026/02/06 19:34:09] Ecoli_core - glucose_iter_990 processed.
# ================================================================================
#
# =================== STARTING: Ecoli_core - glucose_iter_991 ====================
# [2026/02/06 19:34:09] Loading metabolic model: ecoli_core.xml
# [2026/02/06 19:34:09] Loading transcriptomic data: transcriptome_991.csv
# [2026/02/06 19:34:09] Loading known fluxes: knownFluxes_991.csv
# [2026/02/06 19:34:09] Updating model (bounds, medium)...
# Applying medium from: medium.csv
# Starting data pre-processing...
# Capping FPKM values at 95th percentile: 61.6790
# Median 'g' value (E_g) for imputation: 2.7547e+00
# Pre-processing finished in 0.00 seconds.
# [2026/02/06 19:34:09] Running TeraFlux optimization...
# Creating stoichiometric constraints...
# Adding known flux constraints...
# Solving with standard FBA to get an initial guess (x0)...
# Adding known flux constraints...
# R_EX_glc__D_e -9.222853443198105
# {'R_EX_glc__D_e': 9.222853443198105, 'R_EX_nh4_e': inf, 'R_EX_o2_e': inf, 'R_EX_pi_e': inf}
# FBA solution found. Objective value: 0.8454. Status: optimal
# ## Solving the non-linear optimization problem with IPOPT...
# Solver finished. Status: Solve_Succeeded | Success: True
# Optimization took: 0.03 s
# [2026/02/06 19:34:09] Saving results...
# [2026/02/06 19:34:09] Ecoli_core - glucose_iter_991 processed.
# ================================================================================
#
# =================== STARTING: Ecoli_core - glucose_iter_992 ====================
# [2026/02/06 19:34:09] Loading metabolic model: ecoli_core.xml
# [2026/02/06 19:34:09] Loading transcriptomic data: transcriptome_992.csv
# [2026/02/06 19:34:09] Loading known fluxes: knownFluxes_992.csv
# [2026/02/06 19:34:09] Updating model (bounds, medium)...
# Applying medium from: medium.csv
# Starting data pre-processing...
# Capping FPKM values at 95th percentile: 60.4850
# Median 'g' value (E_g) for imputation: 3.8670e+00
# Pre-processing finished in 0.00 seconds.
# [2026/02/06 19:34:10] Running TeraFlux optimization...
# Creating stoichiometric constraints...
# Adding known flux constraints...
# Solving with standard FBA to get an initial guess (x0)...
# Adding known flux constraints...
# R_EX_glc__D_e -9.78405496169909
# {'R_EX_glc__D_e': 9.78405496169909, 'R_EX_nh4_e': inf, 'R_EX_o2_e': inf, 'R_EX_pi_e': inf}
# FBA solution found. Objective value: 0.8969. Status: optimal
# ## Solving the non-linear optimization problem with IPOPT...
# Solver finished. Status: Solve_Succeeded | Success: True
# Optimization took: 0.04 s
# [2026/02/06 19:34:10] Saving results...
# [2026/02/06 19:34:10] Ecoli_core - glucose_iter_992 processed.
# ================================================================================
#
# =================== STARTING: Ecoli_core - glucose_iter_993 ====================
# [2026/02/06 19:34:10] Loading metabolic model: ecoli_core.xml
# [2026/02/06 19:34:10] Loading transcriptomic data: transcriptome_993.csv
# [2026/02/06 19:34:10] Loading known fluxes: knownFluxes_993.csv
# [2026/02/06 19:34:10] Updating model (bounds, medium)...
# Applying medium from: medium.csv
# Starting data pre-processing...
# Capping FPKM values at 95th percentile: 64.5887
# Median 'g' value (E_g) for imputation: 6.6529e+00
# Pre-processing finished in 0.00 seconds.
# [2026/02/06 19:34:10] Running TeraFlux optimization...
# Creating stoichiometric constraints...
# Adding known flux constraints...
# Solving with standard FBA to get an initial guess (x0)...
# Adding known flux constraints...
# R_EX_glc__D_e -9.499915804714524
# {'R_EX_glc__D_e': 9.499915804714524, 'R_EX_nh4_e': inf, 'R_EX_o2_e': inf, 'R_EX_pi_e': inf}
# FBA solution found. Objective value: 0.8708. Status: optimal
# ## Solving the non-linear optimization problem with IPOPT...
# Solver finished. Status: Solve_Succeeded | Success: True
# Optimization took: 0.04 s
# [2026/02/06 19:34:10] Saving results...
# [2026/02/06 19:34:10] Ecoli_core - glucose_iter_993 processed.
# ================================================================================
#
# =================== STARTING: Ecoli_core - glucose_iter_994 ====================
# [2026/02/06 19:34:10] Loading metabolic model: ecoli_core.xml
# [2026/02/06 19:34:10] Loading transcriptomic data: transcriptome_994.csv
# [2026/02/06 19:34:10] Loading known fluxes: knownFluxes_994.csv
# [2026/02/06 19:34:10] Updating model (bounds, medium)...
# Applying medium from: medium.csv
# Starting data pre-processing...
# Capping FPKM values at 95th percentile: 76.5109
# Median 'g' value (E_g) for imputation: 6.0004e+00
# Pre-processing finished in 0.00 seconds.
# [2026/02/06 19:34:10] Running TeraFlux optimization...
# Creating stoichiometric constraints...
# Adding known flux constraints...
# Solving with standard FBA to get an initial guess (x0)...
# Adding known flux constraints...
# R_EX_glc__D_e -9.553738804515875
# {'R_EX_glc__D_e': 9.553738804515875, 'R_EX_nh4_e': inf, 'R_EX_o2_e': inf, 'R_EX_pi_e': inf}
# FBA solution found. Objective value: 0.8757. Status: optimal
# ## Solving the non-linear optimization problem with IPOPT...
# Solver finished. Status: Solve_Succeeded | Success: True
# Optimization took: 0.04 s
# [2026/02/06 19:34:10] Saving results...
# [2026/02/06 19:34:10] Ecoli_core - glucose_iter_994 processed.
# ================================================================================
#
# =================== STARTING: Ecoli_core - glucose_iter_995 ====================
# [2026/02/06 19:34:10] Loading metabolic model: ecoli_core.xml
# [2026/02/06 19:34:11] Loading transcriptomic data: transcriptome_995.csv
# [2026/02/06 19:34:11] Loading known fluxes: knownFluxes_995.csv
# [2026/02/06 19:34:11] Updating model (bounds, medium)...
# Applying medium from: medium.csv
# Starting data pre-processing...
# Capping FPKM values at 95th percentile: 53.0284
# Median 'g' value (E_g) for imputation: 4.2384e+00
# Pre-processing finished in 0.00 seconds.
# [2026/02/06 19:34:11] Running TeraFlux optimization...
# Creating stoichiometric constraints...
# Adding known flux constraints...
# Solving with standard FBA to get an initial guess (x0)...
# Adding known flux constraints...
# R_EX_glc__D_e -9.805833341611864
# {'R_EX_glc__D_e': 9.805833341611864, 'R_EX_nh4_e': inf, 'R_EX_o2_e': inf, 'R_EX_pi_e': inf}
# FBA solution found. Objective value: 0.8988. Status: optimal
# ## Solving the non-linear optimization problem with IPOPT...
# Solver finished. Status: Solve_Succeeded | Success: True
# Optimization took: 0.04 s
# [2026/02/06 19:34:11] Saving results...
# [2026/02/06 19:34:11] Ecoli_core - glucose_iter_995 processed.
# ================================================================================
#
# =================== STARTING: Ecoli_core - glucose_iter_996 ====================
# [2026/02/06 19:34:11] Loading metabolic model: ecoli_core.xml
# [2026/02/06 19:34:11] Loading transcriptomic data: transcriptome_996.csv
# [2026/02/06 19:34:11] Loading known fluxes: knownFluxes_996.csv
# [2026/02/06 19:34:11] Updating model (bounds, medium)...
# Applying medium from: medium.csv
# Starting data pre-processing...
# Capping FPKM values at 95th percentile: 44.4232
# Median 'g' value (E_g) for imputation: 4.0016e+00
# Pre-processing finished in 0.00 seconds.
# [2026/02/06 19:34:11] Running TeraFlux optimization...
# Creating stoichiometric constraints...
# Adding known flux constraints...
# Solving with standard FBA to get an initial guess (x0)...
# Adding known flux constraints...
# R_EX_glc__D_e -9.200729445406704
# {'R_EX_glc__D_e': 9.200729445406704, 'R_EX_nh4_e': inf, 'R_EX_o2_e': inf, 'R_EX_pi_e': inf}
# FBA solution found. Objective value: 0.8434. Status: optimal
# ## Solving the non-linear optimization problem with IPOPT...
# Solver finished. Status: Solve_Succeeded | Success: True
# Optimization took: 0.03 s
# [2026/02/06 19:34:11] Saving results...
# [2026/02/06 19:34:11] Ecoli_core - glucose_iter_996 processed.
# ================================================================================
#
# =================== STARTING: Ecoli_core - glucose_iter_997 ====================
# [2026/02/06 19:34:11] Loading metabolic model: ecoli_core.xml
# [2026/02/06 19:34:11] Loading transcriptomic data: transcriptome_997.csv
# [2026/02/06 19:34:11] Loading known fluxes: knownFluxes_997.csv
# [2026/02/06 19:34:11] Updating model (bounds, medium)...
# Applying medium from: medium.csv
# Starting data pre-processing...
# Capping FPKM values at 95th percentile: 72.0436
# Median 'g' value (E_g) for imputation: 5.9331e+00
# Pre-processing finished in 0.00 seconds.
# [2026/02/06 19:34:11] Running TeraFlux optimization...
# Creating stoichiometric constraints...
# Adding known flux constraints...
# Solving with standard FBA to get an initial guess (x0)...
# Adding known flux constraints...
# R_EX_glc__D_e -9.66335022263584
# {'R_EX_glc__D_e': 9.66335022263584, 'R_EX_nh4_e': inf, 'R_EX_o2_e': inf, 'R_EX_pi_e': inf}
# FBA solution found. Objective value: 0.8858. Status: optimal
# ## Solving the non-linear optimization problem with IPOPT...
# Solver finished. Status: Solve_Succeeded | Success: True
# Optimization took: 0.03 s
# [2026/02/06 19:34:12] Saving results...
# [2026/02/06 19:34:12] Ecoli_core - glucose_iter_997 processed.
# ================================================================================
#
# =================== STARTING: Ecoli_core - glucose_iter_998 ====================
# [2026/02/06 19:34:12] Loading metabolic model: ecoli_core.xml
# [2026/02/06 19:34:12] Loading transcriptomic data: transcriptome_998.csv
# [2026/02/06 19:34:12] Loading known fluxes: knownFluxes_998.csv
# [2026/02/06 19:34:12] Updating model (bounds, medium)...
# Applying medium from: medium.csv
# Starting data pre-processing...
# Capping FPKM values at 95th percentile: 46.8833
# Median 'g' value (E_g) for imputation: 4.7224e+00
# Pre-processing finished in 0.00 seconds.
# [2026/02/06 19:34:12] Running TeraFlux optimization...
# Creating stoichiometric constraints...
# Adding known flux constraints...
# Solving with standard FBA to get an initial guess (x0)...
# Adding known flux constraints...
# R_EX_glc__D_e -9.143355864736565
# {'R_EX_glc__D_e': 9.143355864736565, 'R_EX_nh4_e': inf, 'R_EX_o2_e': inf, 'R_EX_pi_e': inf}
# FBA solution found. Objective value: 0.8381. Status: optimal
# ## Solving the non-linear optimization problem with IPOPT...
# Solver finished. Status: Solve_Succeeded | Success: True
# Optimization took: 0.04 s
# [2026/02/06 19:34:12] Saving results...
# [2026/02/06 19:34:12] Ecoli_core - glucose_iter_998 processed.
# ================================================================================
#
# =================== STARTING: Ecoli_core - glucose_iter_999 ====================
# [2026/02/06 19:34:12] Loading metabolic model: ecoli_core.xml
# [2026/02/06 19:34:12] Loading transcriptomic data: transcriptome_999.csv
# [2026/02/06 19:34:12] Loading known fluxes: knownFluxes_999.csv
# [2026/02/06 19:34:12] Updating model (bounds, medium)...
# Applying medium from: medium.csv
# Starting data pre-processing...
# Capping FPKM values at 95th percentile: 38.4120
# Median 'g' value (E_g) for imputation: 3.4487e+00
# Pre-processing finished in 0.00 seconds.
# [2026/02/06 19:34:12] Running TeraFlux optimization...
# Creating stoichiometric constraints...
# Adding known flux constraints...
# Solving with standard FBA to get an initial guess (x0)...
# Adding known flux constraints...
# R_EX_glc__D_e -9.345260374658253
# {'R_EX_glc__D_e': 9.345260374658253, 'R_EX_nh4_e': inf, 'R_EX_o2_e': inf, 'R_EX_pi_e': inf}
# FBA solution found. Objective value: 0.8566. Status: optimal
# ## Solving the non-linear optimization problem with IPOPT...
# Solver finished. Status: Solve_Succeeded | Success: True
# Optimization took: 0.04 s
# [2026/02/06 19:34:12] Saving results...
# [2026/02/06 19:34:12] Ecoli_core - glucose_iter_999 processed.
# ================================================================================
#
# =============================== PROCESS COMPLETE ===============================
# Summary log saved to: results/teraflux_ecolicore.log.tsv
# Average time per optimization: 0.04 s
# Average time per condition: 0.24 s
# Total process time: 5.49 min (0.09 h)
# Final memory usage: 811.24 MB

# %%
# %pwd
# Out:
# '/home/marcelo/jupyter/teraflux_bkup5feb26/figs2_3/ecoli_core'
