# %%
import cobra
from cobra.io import load_model, read_sbml_model
from cobra.flux_analysis import flux_variability_analysis
import pheflux
import pandas as pd
import scipy
from scipy.stats import pearsonr
import numpy as np
import matplotlib.pyplot as plt
import importlib
import gc
from cobra.sampling import sample
from matplotlib.ticker import MaxNLocator
# Out:
# Welcome to PheFlux !
# /usr/local/lib/python3.10/dist-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "

# %%
import sys
teraflux_path = '../..'
if teraflux_path not in sys.path:
    sys.path.append(teraflux_path)
import teraflux

# También puedes usar la función de autoreload para que Jupyter
# recargue tu librería si haces cambios en el archivo .py
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
organism = "Ecoli"
model_dir = "./gems/iJO1366.xml"
model = read_sbml_model(model_dir)
medium_codes = ["ac","fru","gal","glcn","glc","glyc","pyr","succ"]
reaction_codes = {"ac":"EX_ac_e","fru":"EX_fru_e","gal":"EX_gal_e","glcn":"EX_glcn_e","glc":"EX_glc__D_e","glyc":"EX_glyc_e","pyr":"EX_pyr_e","succ":"EX_succ_e","Growth_rate":"BIOMASS_Ec_iJO1366_WT_53p95M"}

# %%
# Compute max magnitude for the standard bounds set
max_mag = max(
    max(abs(rxn.lower_bound), abs(rxn.upper_bound))
    for rxn in model.reactions
)

# Define standard bounds
STANDARD_BOUNDS = {0.0, max_mag, -max_mag}

for reaction in model.reactions:
    lb = reaction.lower_bound
    ub = reaction.upper_bound
    if lb==0 and ub==0: print(reaction.id,(lb,ub),reaction.bounds,sep="\t")
    # Only process non-standard bounds
    if lb not in STANDARD_BOUNDS or ub not in STANDARD_BOUNDS:

        # Category 1: always positive
        if lb >= 0 and ub > 0:
            reaction.bounds=(0,max_mag)
        # Category 2: always negative
        elif ub <= 0 and lb < 0:
            reaction.bounds=(-max_mag,0)
        # Category 3: crossing zero
        elif lb < 0 < ub:
            reaction.bounds=(-max_mag,max_mag)
        print(reaction.id,(lb,ub),reaction.bounds,sep="\t")
# Out:
# EX_glc__D_e	(-10.0, 1000.0)	(-1000.0, 1000.0)
# EX_cbl1_e	(-0.01, 1000.0)	(-1000.0, 1000.0)
# CAT	(0.0, 0.0)	(0.0, 0.0)
# ATPM	(3.15, 1000.0)	(0, 1000.0)
# DHPTDNR	(0.0, 0.0)	(0.0, 0.0)
# DHPTDNRN	(0.0, 0.0)	(0.0, 0.0)
# FHL	(0.0, 0.0)	(0.0, 0.0)
# SPODM	(0.0, 0.0)	(0.0, 0.0)
# SPODMpp	(0.0, 0.0)	(0.0, 0.0)
# SUCASPtpp	(0.0, 0.0)	(0.0, 0.0)
# SUCFUMtpp	(0.0, 0.0)	(0.0, 0.0)
# SUCMALtpp	(0.0, 0.0)	(0.0, 0.0)
# SUCTARTtpp	(0.0, 0.0)	(0.0, 0.0)

# %%
# Create medium file
for medium_code in medium_codes:
    model = load_model("iJO1366")
    model.reactions.EX_cbl1_e.lower_bound=-1000
    model.reactions.ATPM.lower_bound=0
    model.reactions.EX_ac_e.bounds
    wt_biomass = model.reactions.get_by_id("BIOMASS_Ec_iJO1366_WT_53p95M")
    core_biomass = model.reactions.get_by_id("BIOMASS_Ec_iJO1366_core_53p95M")
    model.objective = wt_biomass
    model.reactions.EX_cbl1_e.lower_bound=-1000
    model.reactions.ATPM.lower_bound=0
    model.reactions.EX_glc__D_e.bounds=(0,1000)
    model.reactions.get_by_id(reaction_codes[medium_code]).bounds=(-10.14,1000)
    model.objective = wt_biomass
    solution=model.optimize()
    print(medium_code)
    print(model.summary())
    with open(f'mediums/Ecoli_Medium_{medium_code}.csv', 'w', newline="\n") as f:
        print("Metabolite_Name", "Reaction_ID", sep="\t", file=f)
        for reaction in model.summary().uptake_flux.index:
            metabolite = reaction.split("_")[1]
            print(metabolite, reaction, sep="\t", file=f)
# Out:
# ac
# Objective
# =========
# 1.0 BIOMASS_Ec_iJO1366_WT_53p95M = 0.2644732708848971
#
# Uptake
# ------
# Metabolite     Reaction      Flux  C-Number C-Flux
#       ac_e      EX_ac_e     10.14         2 99.98%
#      ca2_e     EX_ca2_e   0.00131         0  0.00%
#     cbl1_e    EX_cbl1_e 5.898E-05        62  0.02%
#       cl_e      EX_cl_e   0.00131         0  0.00%
#  cobalt2_e EX_cobalt2_e 6.347E-06         0  0.00%
#      cu2_e     EX_cu2_e 0.0001783         0  0.00%
#      fe2_e     EX_fe2_e  0.004106         0  0.00%
#        h_e       EX_h_e     7.793         0  0.00%
#        k_e       EX_k_e   0.04911         0  0.00%
#      mg2_e     EX_mg2_e  0.002183         0  0.00%
#      mn2_e     EX_mn2_e  0.000174         0  0.00%
#     mobd_e    EX_mobd_e 3.623E-05         0  0.00%
#      nh4_e     EX_nh4_e     2.779         0  0.00%
#      ni2_e     EX_ni2_e 8.119E-05         0  0.00%
#       o2_e      EX_o2_e     8.926         0  0.00%
#       pi_e      EX_pi_e    0.2452         0  0.00%
#      so4_e     EX_so4_e   0.06664         0  0.00%
#      zn2_e     EX_zn2_e 8.569E-05         0  0.00%
#
# Secretion
# ---------
# Metabolite    Reaction       Flux  C-Number C-Flux
#   4crsol_c DM_4crsol_c -5.898E-05         7  0.00%
#    5drib_c  DM_5drib_c -6.109E-05         5  0.00%
#     amob_c   DM_amob_c -5.289E-07        15  0.00%
#   mththf_c DM_mththf_c -0.0003544         5  0.02%
#     5mtr_e   EX_5mtr_e  -0.001784         6  0.11%
#      co2_e    EX_co2_e     -9.464         1 99.86%
#      h2o_e    EX_h2o_e     -16.28         0  0.00%
#     meoh_e   EX_meoh_e -5.289E-07         1  0.00%
#
# fru
# Objective
# =========
# 1.0 BIOMASS_Ec_iJO1366_WT_53p95M = 1.0136295368818666
#
# Uptake
# ------
# Metabolite     Reaction      Flux  C-Number C-Flux
#      ca2_e     EX_ca2_e  0.005019         0  0.00%
#     cbl1_e    EX_cbl1_e  0.000226        62  0.02%
#       cl_e      EX_cl_e  0.005019         0  0.00%
#  cobalt2_e EX_cobalt2_e 2.433E-05         0  0.00%
#      cu2_e     EX_cu2_e 0.0006832         0  0.00%
#      fe2_e     EX_fe2_e   0.01574         0  0.00%
#      fru_e     EX_fru_e     10.14         6 99.98%
#        k_e       EX_k_e    0.1882         0  0.00%
#      mg2_e     EX_mg2_e  0.008365         0  0.00%
#      mn2_e     EX_mn2_e  0.000667         0  0.00%
#     mobd_e    EX_mobd_e 0.0001389         0  0.00%
#      nh4_e     EX_nh4_e     10.65         0  0.00%
#      ni2_e     EX_ni2_e 0.0003112         0  0.00%
#       o2_e      EX_o2_e     17.33         0  0.00%
#       pi_e      EX_pi_e    0.9398         0  0.00%
#      so4_e     EX_so4_e    0.2554         0  0.00%
#      zn2_e     EX_zn2_e 0.0003284         0  0.00%
#
# Secretion
# ---------
# Metabolite    Reaction       Flux  C-Number C-Flux
#   4crsol_c DM_4crsol_c  -0.000226         7  0.01%
#    5drib_c  DM_5drib_c -0.0002341         5  0.01%
#     amob_c   DM_amob_c -2.027E-06        15  0.00%
#   mththf_c DM_mththf_c  -0.001358         5  0.03%
#     5mtr_e   EX_5mtr_e  -0.006836         6  0.21%
#      co2_e    EX_co2_e     -19.39         1 99.74%
#      h2o_e    EX_h2o_e     -45.53         0  0.00%
#        h_e      EX_h_e     -8.994         0  0.00%
#     meoh_e   EX_meoh_e -2.027E-06         1  0.00%
#
# gal
# Objective
# =========
# 1.0 BIOMASS_Ec_iJO1366_WT_53p95M = 1.0030708958726926
#
# Uptake
# ------
# Metabolite     Reaction      Flux  C-Number C-Flux
#      ca2_e     EX_ca2_e  0.004967         0  0.00%
#     cbl1_e    EX_cbl1_e 0.0002237        62  0.02%
#       cl_e      EX_cl_e  0.004967         0  0.00%
#  cobalt2_e EX_cobalt2_e 2.407E-05         0  0.00%
#      cu2_e     EX_cu2_e 0.0006761         0  0.00%
#      fe2_e     EX_fe2_e   0.01557         0  0.00%
#      gal_e     EX_gal_e     10.14         6 99.98%
#        k_e       EX_k_e    0.1863         0  0.00%
#      mg2_e     EX_mg2_e  0.008278         0  0.00%
#      mn2_e     EX_mn2_e   0.00066         0  0.00%
#     mobd_e    EX_mobd_e 0.0001374         0  0.00%
#      nh4_e     EX_nh4_e     10.54         0  0.00%
#      ni2_e     EX_ni2_e 0.0003079         0  0.00%
#       o2_e      EX_o2_e     17.78         0  0.00%
#       pi_e      EX_pi_e      0.93         0  0.00%
#      so4_e     EX_so4_e    0.2528         0  0.00%
#      zn2_e     EX_zn2_e  0.000325         0  0.00%
#
# Secretion
# ---------
# Metabolite    Reaction       Flux  C-Number C-Flux
#   4crsol_c DM_4crsol_c -0.0002237         7  0.01%
#    5drib_c  DM_5drib_c -0.0002317         5  0.01%
#     amob_c   DM_amob_c -2.006E-06        15  0.00%
#   mththf_c DM_mththf_c  -0.001344         5  0.03%
#     5mtr_e   EX_5mtr_e  -0.006765         6  0.20%
#      co2_e    EX_co2_e     -19.82         1 99.75%
#      h2o_e    EX_h2o_e     -45.69         0  0.00%
#        h_e      EX_h_e       -8.9         0  0.00%
#     meoh_e   EX_meoh_e -2.006E-06         1  0.00%
#
# glcn
# Objective
# =========
# 1.0 BIOMASS_Ec_iJO1366_WT_53p95M = 0.926957197794775
#
# Uptake
# ------
# Metabolite     Reaction      Flux  C-Number C-Flux
#      ca2_e     EX_ca2_e   0.00459         0  0.00%
#     cbl1_e    EX_cbl1_e 0.0002067        62  0.02%
#       cl_e      EX_cl_e   0.00459         0  0.00%
#  cobalt2_e EX_cobalt2_e 2.225E-05         0  0.00%
#      cu2_e     EX_cu2_e 0.0006248         0  0.00%
#      fe2_e     EX_fe2_e   0.01439         0  0.00%
#     glcn_e    EX_glcn_e     10.14         6 99.98%
#        h_e       EX_h_e     1.915         0  0.00%
#        k_e       EX_k_e    0.1721         0  0.00%
#      mg2_e     EX_mg2_e   0.00765         0  0.00%
#      mn2_e     EX_mn2_e 0.0006099         0  0.00%
#     mobd_e    EX_mobd_e  0.000127         0  0.00%
#      nh4_e     EX_nh4_e     9.739         0  0.00%
#      ni2_e     EX_ni2_e 0.0002846         0  0.00%
#       o2_e      EX_o2_e     15.98         0  0.00%
#       pi_e      EX_pi_e    0.8594         0  0.00%
#      so4_e     EX_so4_e    0.2336         0  0.00%
#      zn2_e     EX_zn2_e 0.0003003         0  0.00%
#
# Secretion
# ---------
# Metabolite    Reaction       Flux  C-Number C-Flux
#   4crsol_c DM_4crsol_c -0.0002067         7  0.01%
#    5drib_c  DM_5drib_c -0.0002141         5  0.00%
#     amob_c   DM_amob_c -1.854E-06        15  0.00%
#   mththf_c DM_mththf_c  -0.001242         5  0.03%
#     5mtr_e   EX_5mtr_e  -0.006251         6  0.16%
#      co2_e    EX_co2_e     -22.93         1 99.80%
#      h2o_e    EX_h2o_e     -46.84         0  0.00%
#     meoh_e   EX_meoh_e -1.854E-06         1  0.00%
#
# glc
# Objective
# =========
# 1.0 BIOMASS_Ec_iJO1366_WT_53p95M = 1.0136295368818815
#
# Uptake
# ------
# Metabolite     Reaction      Flux  C-Number C-Flux
#      ca2_e     EX_ca2_e  0.005019         0  0.00%
#     cbl1_e    EX_cbl1_e  0.000226        62  0.02%
#       cl_e      EX_cl_e  0.005019         0  0.00%
#  cobalt2_e EX_cobalt2_e 2.433E-05         0  0.00%
#      cu2_e     EX_cu2_e 0.0006832         0  0.00%
#      fe2_e     EX_fe2_e   0.01574         0  0.00%
#   glc__D_e  EX_glc__D_e     10.14         6 99.98%
#        k_e       EX_k_e    0.1882         0  0.00%
#      mg2_e     EX_mg2_e  0.008365         0  0.00%
#      mn2_e     EX_mn2_e  0.000667         0  0.00%
#     mobd_e    EX_mobd_e 0.0001389         0  0.00%
#      nh4_e     EX_nh4_e     10.65         0  0.00%
#      ni2_e     EX_ni2_e 0.0003112         0  0.00%
#       o2_e      EX_o2_e     17.33         0  0.00%
#       pi_e      EX_pi_e    0.9398         0  0.00%
#      so4_e     EX_so4_e    0.2554         0  0.00%
#      zn2_e     EX_zn2_e 0.0003284         0  0.00%
#
# Secretion
# ---------
# Metabolite    Reaction       Flux  C-Number C-Flux
#   4crsol_c DM_4crsol_c  -0.000226         7  0.01%
#    5drib_c  DM_5drib_c -0.0002341         5  0.01%
#     amob_c   DM_amob_c -2.027E-06        15  0.00%
#   mththf_c DM_mththf_c  -0.001358         5  0.03%
#     5mtr_e   EX_5mtr_e  -0.006836         6  0.21%
#      co2_e    EX_co2_e     -19.39         1 99.74%
#      h2o_e    EX_h2o_e     -45.53         0  0.00%
#        h_e      EX_h_e     -8.994         0  0.00%
#     meoh_e   EX_meoh_e -2.027E-06         1  0.00%
#
# glyc
# Objective
# =========
# 1.0 BIOMASS_Ec_iJO1366_WT_53p95M = 0.5865901017295053
#
# Uptake
# ------
# Metabolite     Reaction      Flux  C-Number C-Flux
#      ca2_e     EX_ca2_e  0.002905         0  0.00%
#     cbl1_e    EX_cbl1_e 0.0001308        62  0.03%
#       cl_e      EX_cl_e  0.002905         0  0.00%
#  cobalt2_e EX_cobalt2_e 1.408E-05         0  0.00%
#      cu2_e     EX_cu2_e 0.0003954         0  0.00%
#      fe2_e     EX_fe2_e  0.009108         0  0.00%
#     glyc_e    EX_glyc_e     10.14         3 99.97%
#        k_e       EX_k_e    0.1089         0  0.00%
#      mg2_e     EX_mg2_e  0.004841         0  0.00%
#      mn2_e     EX_mn2_e  0.000386         0  0.00%
#     mobd_e    EX_mobd_e 8.036E-05         0  0.00%
#      nh4_e     EX_nh4_e     6.163         0  0.00%
#      ni2_e     EX_ni2_e 0.0001801         0  0.00%
#       o2_e      EX_o2_e     10.31         0  0.00%
#       pi_e      EX_pi_e    0.5439         0  0.00%
#      so4_e     EX_so4_e    0.1478         0  0.00%
#      zn2_e     EX_zn2_e 0.0001901         0  0.00%
#
# Secretion
# ---------
# Metabolite    Reaction       Flux  C-Number C-Flux
#   4crsol_c DM_4crsol_c -0.0001308         7  0.01%
#    5drib_c  DM_5drib_c -0.0001355         5  0.01%
#     amob_c   DM_amob_c -1.173E-06        15  0.00%
#   mththf_c DM_mththf_c  -0.000786         5  0.06%
#     5mtr_e   EX_5mtr_e  -0.003956         6  0.37%
#      co2_e    EX_co2_e     -6.432         1 99.55%
#      h2o_e    EX_h2o_e      -31.7         0  0.00%
#        h_e      EX_h_e     -5.205         0  0.00%
#     meoh_e   EX_meoh_e -1.173E-06         1  0.00%
#
# pyr
# Objective
# =========
# 1.0 BIOMASS_Ec_iJO1366_WT_53p95M = 0.378451736776421
#
# Uptake
# ------
# Metabolite     Reaction      Flux  C-Number C-Flux
#      ca2_e     EX_ca2_e  0.001874         0  0.00%
#     cbl1_e    EX_cbl1_e 8.439E-05        62  0.02%
#       cl_e      EX_cl_e  0.001874         0  0.00%
#  cobalt2_e EX_cobalt2_e 9.083E-06         0  0.00%
#      cu2_e     EX_cu2_e 0.0002551         0  0.00%
#      fe2_e     EX_fe2_e  0.005876         0  0.00%
#        h_e       EX_h_e     6.782         0  0.00%
#        k_e       EX_k_e   0.07027         0  0.00%
#      mg2_e     EX_mg2_e  0.003123         0  0.00%
#      mn2_e     EX_mn2_e  0.000249         0  0.00%
#     mobd_e    EX_mobd_e 5.185E-05         0  0.00%
#      nh4_e     EX_nh4_e     3.976         0  0.00%
#      ni2_e     EX_ni2_e 0.0001162         0  0.00%
#       o2_e      EX_o2_e     9.103         0  0.00%
#       pi_e      EX_pi_e    0.3509         0  0.00%
#      pyr_e     EX_pyr_e     10.14         3 99.98%
#      so4_e     EX_so4_e   0.09536         0  0.00%
#      zn2_e     EX_zn2_e 0.0001226         0  0.00%
#
# Secretion
# ---------
# Metabolite    Reaction       Flux  C-Number C-Flux
#   4crsol_c DM_4crsol_c -8.439E-05         7  0.00%
#    5drib_c  DM_5drib_c -8.742E-05         5  0.00%
#     amob_c   DM_amob_c -7.569E-07        15  0.00%
#   mththf_c DM_mththf_c -0.0005071         5  0.02%
#     5mtr_e   EX_5mtr_e  -0.002552         6  0.10%
#      co2_e    EX_co2_e     -14.94         1 99.87%
#      h2o_e    EX_h2o_e     -14.56         0  0.00%
#     meoh_e   EX_meoh_e -7.569E-07         1  0.00%
#
# succ
# Objective
# =========
# 1.0 BIOMASS_Ec_iJO1366_WT_53p95M = 0.5146792362283884
#
# Uptake
# ------
# Metabolite     Reaction      Flux  C-Number C-Flux
#      ca2_e     EX_ca2_e  0.002549         0  0.00%
#     cbl1_e    EX_cbl1_e 0.0001148        62  0.02%
#       cl_e      EX_cl_e  0.002549         0  0.00%
#  cobalt2_e EX_cobalt2_e 1.235E-05         0  0.00%
#      cu2_e     EX_cu2_e 0.0003469         0  0.00%
#      fe2_e     EX_fe2_e  0.007991         0  0.00%
#        h_e       EX_h_e     15.71         0  0.00%
#        k_e       EX_k_e   0.09557         0  0.00%
#      mg2_e     EX_mg2_e  0.004248         0  0.00%
#      mn2_e     EX_mn2_e 0.0003387         0  0.00%
#     mobd_e    EX_mobd_e 7.051E-05         0  0.00%
#      nh4_e     EX_nh4_e     5.407         0  0.00%
#      ni2_e     EX_ni2_e  0.000158         0  0.00%
#       o2_e      EX_o2_e      13.4         0  0.00%
#       pi_e      EX_pi_e    0.4772         0  0.00%
#      so4_e     EX_so4_e    0.1297         0  0.00%
#     succ_e    EX_succ_e     10.14         4 99.98%
#      zn2_e     EX_zn2_e 0.0001668         0  0.00%
#
# Secretion
# ---------
# Metabolite    Reaction       Flux  C-Number C-Flux
#   4crsol_c DM_4crsol_c -0.0001148         7  0.00%
#    5drib_c  DM_5drib_c -0.0001189         5  0.00%
#     amob_c   DM_amob_c -1.029E-06        15  0.00%
#   mththf_c DM_mththf_c -0.0006897         5  0.02%
#     5mtr_e   EX_5mtr_e  -0.003471         6  0.11%
#      co2_e    EX_co2_e     -19.51         1 99.87%
#      h2o_e    EX_h2o_e     -22.64         0  0.00%
#     meoh_e   EX_meoh_e -1.029E-06         1  0.00%

# %%
# Filter the known fluxes to just output the glucose consumption and biomass growth rate
for medium_code in medium_codes:
    
    experimentalFile=f"./experimental/Ecoli/Ecoli_Fluxfile_{medium_code}.csv"
    known_fluxes_filename   =f"./knownFluxes/{organism}/{organism}_knownFluxes_{medium_code}.csv" 
    experimental = pd.read_csv(experimentalFile,index_col=0,sep="\t")
    reactions = [reaction_codes[medium_code],reaction_codes["Growth_rate"] ]

    
    with open(known_fluxes_filename, 'w', newline="\n") as f:
        print("Reaction_ID", "Metabolite_ID", "Reaction_Flux", sep="\t", file=f)
        for Reaction_ID in reactions:
            Metabolite_ID = Reaction_ID
            if Reaction_ID == "BIOMASS_Ec_iJO1366_WT_53p95M":
                Reaction_Flux = experimental.loc["Growth_rate"].Flux 
            else:
                Reaction_Flux = experimental.loc[Reaction_ID].Flux 
            print(Reaction_ID, Metabolite_ID, Reaction_Flux, sep="\t", file=f)

# %%
# Run pheflux

for medium_code in ["ac","gal"]:#medium_codes:
    # Create InputData file
    input_file_name = f"inputData_{organism}_{medium_code}.csv"
    with open(input_file_name, 'w', newline="\n") as f:
        print("Organism\tCondition\tGeneExpFile\tMedium\tNetwork\tKnownFluxes", file=f)    
        Organism = organism
        Condition = medium_code
        GeneExpFile = f"./transcriptomes/{organism}/{organism}_Expfile_{medium_code}.csv"
        Medium = f"./mediums/{organism}_Medium_{medium_code}.csv"
        Network = model_dir 
        KnownFluxes = f"./knownFluxes/{organism}/{organism}_knownFluxes_{medium_code}.csv"
        print(Organism, Condition, GeneExpFile, Medium, Network,KnownFluxes, sep="\t", file=f)

    # Save results
    resultsDir = "./results/pheflux/"
    prefix_log_file = f"{organism}_phe_{medium_code}"
    verbosity = True
    fluxes = pheflux.getFluxes(input_file_name, resultsDir, prefix_log_file, verbosity)

# %%
# Run teraflux

for medium_code in medium_codes:
    # Create  InputData file
    input_file_name = f"inputData_{organism}_{medium_code}.csv"
    with open(input_file_name, 'w', newline="\n") as f:
        print("Organism\tCondition\tGeneExpFile\tMedium\tNetwork\tKnownFluxes", file=f)    
        Organism = organism
        Condition = medium_code
        GeneExpFile = f"./transcriptomes/{organism}/{organism}_Expfile_{medium_code}.csv"
        Medium =      f"./mediums/{organism}_Medium_{medium_code}.csv"
        Network = model_dir 
        KnownFluxes = f"./knownFluxes/{organism}/{organism}_knownFluxes_{medium_code}.csv"
        print(Organism, Condition, GeneExpFile, Medium, Network,KnownFluxes, sep="\t", file=f)

    # Save results
    resultsDir = "./results/teraflux/"
    prefix_log_file = f"{organism}_{medium_code}"
    ipoptParams={
            'print_level': 0, # Suppress solver output for cleaner logs
            'sb': 'yes',       # Suppress IPOPT banner
            'tol': 1e-10,       # Overall tolerance (e.g., 1e-8, 1e-10, etc.)
            'acceptable_tol': 1e-10, # Allowable tolerance before giving up
            'max_iter': 6500,   # Increase maximum iterations if needed
            'nlp_scaling_method' : 'none',
            'constr_viol_tol' : 1e-10,
            'nlp_scaling_method': 'gradient-based',
            'hessian_approximation': 'exact',
        }
    fluxes,fr,lagrange = teraflux.getFluxes(input_file_name, resultsDir, prefix_log_file, ipoptParams)
# Out:
# Found 1 conditions to process.
#
# ============================= STARTING: Ecoli - ac =============================
# [2026/02/07 03:35:39] Loading metabolic model: iJO1366.xml
# [2026/02/07 03:35:40] Loading transcriptomic data: Ecoli_Expfile_ac.csv
# [2026/02/07 03:35:40] Loading known fluxes: Ecoli_knownFluxes_ac.csv
# [2026/02/07 03:35:40] Updating model (bounds, medium)...
# Applying medium from: ./mediums/Ecoli_Medium_ac.csv
# Starting data pre-processing...
# Capping FPKM values at 95th percentile: 23639.3906
# Median 'g' value (E_g) for imputation: 3.8060e+03
# Pre-processing finished in 0.01 seconds.
# [2026/02/07 03:35:41] Running TeraFlux optimization...
# Creating stoichiometric constraints...
# Adding known flux constraints...
# Solving with standard FBA to get an initial guess (x0)...
# R_BIOMASS_Ec_iJO1366_core_53p95M
# Adding known flux constraints...
# R_EX_ac_e -13.584
# R_BIOMASS_Ec_iJO1366_WT_53p95M 0.29
# {'R_EX_cobalt2_e': inf, 'R_EX_h_e': inf, 'R_EX_k_e': inf, 'R_EX_ac_e': 13.584, 'R_EX_cu2_e': inf, 'R_EX_mg2_e': inf, 'R_EX_mn2_e': inf, 'R_EX_mobd_e': inf, 'R_EX_nh4_e': inf, 'R_EX_ca2_e': inf, 'R_EX_cbl1_e': inf, 'R_EX_ni2_e': inf, 'R_EX_o2_e': inf, 'R_EX_cl_e': inf, 'R_EX_pi_e': inf, 'R_EX_zn2_e': inf, 'R_EX_so4_e': inf, 'R_EX_fe2_e': inf}
# FBA solution found. Objective value: 0.0642. Status: optimal
# ## Solving the non-linear optimization problem with IPOPT...
# Solver finished. Status: Solve_Succeeded | Success: True
# Optimization took: 1.12 s
# [2026/02/07 03:35:45] Saving results...
# [2026/02/07 03:35:45] Ecoli - ac processed.
# ================================================================================
#
# =============================== PROCESS COMPLETE ===============================
# Summary log saved to: results/teraflux/Ecoli_ac.log.tsv
# Average time per optimization: 1.12 s
# Average time per condition: 3.39 s
# Total process time: 0.10 min (0.00 h)
# Final memory usage: 1995.78 MB
# Found 1 conditions to process.
#
# ============================ STARTING: Ecoli - fru =============================
# [2026/02/07 03:35:45] Loading metabolic model: iJO1366.xml
# [2026/02/07 03:35:46] Loading transcriptomic data: Ecoli_Expfile_fru.csv
# [2026/02/07 03:35:46] Loading known fluxes: Ecoli_knownFluxes_fru.csv
# [2026/02/07 03:35:46] Updating model (bounds, medium)...
# Applying medium from: ./mediums/Ecoli_Medium_fru.csv
# Starting data pre-processing...
# Capping FPKM values at 95th percentile: 24258.8175
# Median 'g' value (E_g) for imputation: 3.7438e+03
# Pre-processing finished in 0.01 seconds.
# [2026/02/07 03:35:47] Running TeraFlux optimization...
# Creating stoichiometric constraints...
# Adding known flux constraints...
# Solving with standard FBA to get an initial guess (x0)...
# R_BIOMASS_Ec_iJO1366_core_53p95M
# Adding known flux constraints...
# R_EX_fru_e -8.328
# R_BIOMASS_Ec_iJO1366_WT_53p95M 0.4924
# {'R_EX_cobalt2_e': inf, 'R_EX_k_e': inf, 'R_EX_cu2_e': inf, 'R_EX_mg2_e': inf, 'R_EX_mn2_e': inf, 'R_EX_mobd_e': inf, 'R_EX_nh4_e': inf, 'R_EX_ca2_e': inf, 'R_EX_cbl1_e': inf, 'R_EX_ni2_e': inf, 'R_EX_o2_e': inf, 'R_EX_cl_e': inf, 'R_EX_pi_e': inf, 'R_EX_zn2_e': inf, 'R_EX_so4_e': inf, 'R_EX_fe2_e': inf, 'R_EX_fru_e': 8.328}
# FBA solution found. Objective value: 0.3387. Status: optimal
# ## Solving the non-linear optimization problem with IPOPT...
# Solver finished. Status: Solve_Succeeded | Success: True
# Optimization took: 1.05 s
# [2026/02/07 03:35:50] Saving results...
# [2026/02/07 03:35:50] Ecoli - fru processed.
# ================================================================================
#
# =============================== PROCESS COMPLETE ===============================
# Summary log saved to: results/teraflux/Ecoli_fru.log.tsv
# Average time per optimization: 1.05 s
# Average time per condition: 3.35 s
# Total process time: 0.10 min (0.00 h)
# Final memory usage: 2024.91 MB
# Found 1 conditions to process.
#
# ============================ STARTING: Ecoli - gal =============================
# [2026/02/07 03:35:50] Loading metabolic model: iJO1366.xml
# [2026/02/07 03:35:52] Loading transcriptomic data: Ecoli_Expfile_gal.csv
# [2026/02/07 03:35:52] Loading known fluxes: Ecoli_knownFluxes_gal.csv
# [2026/02/07 03:35:52] Updating model (bounds, medium)...
# Applying medium from: ./mediums/Ecoli_Medium_gal.csv
# Starting data pre-processing...
# Capping FPKM values at 95th percentile: 22979.2713
# Median 'g' value (E_g) for imputation: 3.1690e+03
# Pre-processing finished in 0.01 seconds.
# [2026/02/07 03:35:53] Running TeraFlux optimization...
# Creating stoichiometric constraints...
# Adding known flux constraints...
# Solving with standard FBA to get an initial guess (x0)...
# R_BIOMASS_Ec_iJO1366_core_53p95M
# Adding known flux constraints...
# R_EX_gal_e -1.969
# R_BIOMASS_Ec_iJO1366_WT_53p95M 0.18
# {'R_EX_cobalt2_e': inf, 'R_EX_k_e': inf, 'R_EX_cu2_e': inf, 'R_EX_mg2_e': inf, 'R_EX_mn2_e': inf, 'R_EX_mobd_e': inf, 'R_EX_nh4_e': inf, 'R_EX_ca2_e': inf, 'R_EX_cbl1_e': inf, 'R_EX_ni2_e': inf, 'R_EX_o2_e': inf, 'R_EX_cl_e': inf, 'R_EX_pi_e': inf, 'R_EX_zn2_e': inf, 'R_EX_so4_e': inf, 'R_EX_fe2_e': inf, 'R_EX_gal_e': 1.969}
# FBA solution found. Objective value: 0.0147. Status: optimal
# ## Solving the non-linear optimization problem with IPOPT...
# Solver finished. Status: Solve_Succeeded | Success: True
# Optimization took: 0.97 s
# [2026/02/07 03:35:56] Saving results...
# [2026/02/07 03:35:56] Ecoli - gal processed.
# ================================================================================
#
# =============================== PROCESS COMPLETE ===============================
# Summary log saved to: results/teraflux/Ecoli_gal.log.tsv
# Average time per optimization: 0.97 s
# Average time per condition: 3.28 s
# Total process time: 0.10 min (0.00 h)
# Final memory usage: 2052.11 MB
# Found 1 conditions to process.
#
# ============================ STARTING: Ecoli - glcn ============================
# [2026/02/07 03:35:56] Loading metabolic model: iJO1366.xml
# [2026/02/07 03:35:57] Loading transcriptomic data: Ecoli_Expfile_glcn.csv
# [2026/02/07 03:35:57] Loading known fluxes: Ecoli_knownFluxes_glcn.csv
# [2026/02/07 03:35:57] Updating model (bounds, medium)...
# Applying medium from: ./mediums/Ecoli_Medium_glcn.csv
# Starting data pre-processing...
# Capping FPKM values at 95th percentile: 24538.9144
# Median 'g' value (E_g) for imputation: 3.9379e+03
# Pre-processing finished in 0.01 seconds.
# [2026/02/07 03:35:59] Running TeraFlux optimization...
# Creating stoichiometric constraints...
# Adding known flux constraints...
# Solving with standard FBA to get an initial guess (x0)...
# R_BIOMASS_Ec_iJO1366_core_53p95M
# Adding known flux constraints...
# R_EX_glcn_e -7.2839
# R_BIOMASS_Ec_iJO1366_WT_53p95M 0.59
# {'R_EX_cobalt2_e': inf, 'R_EX_glcn_e': 7.2839, 'R_EX_h_e': inf, 'R_EX_k_e': inf, 'R_EX_cu2_e': inf, 'R_EX_mg2_e': inf, 'R_EX_mn2_e': inf, 'R_EX_mobd_e': inf, 'R_EX_nh4_e': inf, 'R_EX_ca2_e': inf, 'R_EX_cbl1_e': inf, 'R_EX_ni2_e': inf, 'R_EX_o2_e': inf, 'R_EX_cl_e': inf, 'R_EX_pi_e': inf, 'R_EX_zn2_e': inf, 'R_EX_so4_e': inf, 'R_EX_fe2_e': inf}
# FBA solution found. Objective value: 0.0756. Status: optimal
# ## Solving the non-linear optimization problem with IPOPT...
# Solver finished. Status: Solve_Succeeded | Success: True
# Optimization took: 1.13 s
# [2026/02/07 03:36:02] Saving results...
# [2026/02/07 03:36:02] Ecoli - glcn processed.
# ================================================================================
#
# =============================== PROCESS COMPLETE ===============================
# Summary log saved to: results/teraflux/Ecoli_glcn.log.tsv
# Average time per optimization: 1.13 s
# Average time per condition: 3.46 s
# Total process time: 0.10 min (0.00 h)
# Final memory usage: 2081.25 MB
# Found 1 conditions to process.
#
# ============================ STARTING: Ecoli - glc =============================
# [2026/02/07 03:36:02] Loading metabolic model: iJO1366.xml
# [2026/02/07 03:36:03] Loading transcriptomic data: Ecoli_Expfile_glc.csv
# [2026/02/07 03:36:03] Loading known fluxes: Ecoli_knownFluxes_glc.csv
# [2026/02/07 03:36:03] Updating model (bounds, medium)...
# Applying medium from: ./mediums/Ecoli_Medium_glc.csv
# Starting data pre-processing...
# Capping FPKM values at 95th percentile: 24351.2100
# Median 'g' value (E_g) for imputation: 3.7548e+03
# Pre-processing finished in 0.01 seconds.
# [2026/02/07 03:36:05] Running TeraFlux optimization...
# Creating stoichiometric constraints...
# Adding known flux constraints...
# Solving with standard FBA to get an initial guess (x0)...
# R_BIOMASS_Ec_iJO1366_core_53p95M
# Adding known flux constraints...
# R_EX_glc__D_e -9.654
# R_BIOMASS_Ec_iJO1366_WT_53p95M 0.65
# {'R_EX_cobalt2_e': inf, 'R_EX_glc__D_e': 9.654, 'R_EX_k_e': inf, 'R_EX_cu2_e': inf, 'R_EX_mg2_e': inf, 'R_EX_mn2_e': inf, 'R_EX_mobd_e': inf, 'R_EX_nh4_e': inf, 'R_EX_ca2_e': inf, 'R_EX_cbl1_e': inf, 'R_EX_ni2_e': inf, 'R_EX_o2_e': inf, 'R_EX_cl_e': inf, 'R_EX_pi_e': inf, 'R_EX_zn2_e': inf, 'R_EX_so4_e': inf, 'R_EX_fe2_e': inf}
# FBA solution found. Objective value: 0.3137. Status: optimal
# ## Solving the non-linear optimization problem with IPOPT...
# Solver finished. Status: Solve_Succeeded | Success: True
# Optimization took: 1.11 s
# [2026/02/07 03:36:08] Saving results...
# [2026/02/07 03:36:08] Ecoli - glc processed.
# ================================================================================
#
# =============================== PROCESS COMPLETE ===============================
# Summary log saved to: results/teraflux/Ecoli_glc.log.tsv
# Average time per optimization: 1.11 s
# Average time per condition: 3.46 s
# Total process time: 0.10 min (0.00 h)
# Final memory usage: 2108.95 MB
# Found 1 conditions to process.
#
# ============================ STARTING: Ecoli - glyc ============================
# [2026/02/07 03:36:08] Loading metabolic model: iJO1366.xml
# [2026/02/07 03:36:09] Loading transcriptomic data: Ecoli_Expfile_glyc.csv
# [2026/02/07 03:36:09] Loading known fluxes: Ecoli_knownFluxes_glyc.csv
# [2026/02/07 03:36:09] Updating model (bounds, medium)...
# Applying medium from: ./mediums/Ecoli_Medium_glyc.csv
# Starting data pre-processing...
# Capping FPKM values at 95th percentile: 24351.1048
# Median 'g' value (E_g) for imputation: 3.8231e+03
# Pre-processing finished in 0.01 seconds.
# [2026/02/07 03:36:11] Running TeraFlux optimization...
# Creating stoichiometric constraints...
# Adding known flux constraints...
# Solving with standard FBA to get an initial guess (x0)...
# R_BIOMASS_Ec_iJO1366_core_53p95M
# Adding known flux constraints...
# R_EX_glyc_e -10.14
# R_BIOMASS_Ec_iJO1366_WT_53p95M 0.49
# {'R_EX_cobalt2_e': inf, 'R_EX_glyc_e': 10.14, 'R_EX_k_e': inf, 'R_EX_cu2_e': inf, 'R_EX_mg2_e': inf, 'R_EX_mn2_e': inf, 'R_EX_mobd_e': inf, 'R_EX_nh4_e': inf, 'R_EX_ca2_e': inf, 'R_EX_cbl1_e': inf, 'R_EX_ni2_e': inf, 'R_EX_o2_e': inf, 'R_EX_cl_e': inf, 'R_EX_pi_e': inf, 'R_EX_zn2_e': inf, 'R_EX_so4_e': inf, 'R_EX_fe2_e': inf}
# FBA solution found. Objective value: 0.0962. Status: optimal
# ## Solving the non-linear optimization problem with IPOPT...
# Solver finished. Status: Solve_Succeeded | Success: True
# Optimization took: 1.09 s
# [2026/02/07 03:36:14] Saving results...
# [2026/02/07 03:36:14] Ecoli - glyc processed.
# ================================================================================
#
# =============================== PROCESS COMPLETE ===============================
# Summary log saved to: results/teraflux/Ecoli_glyc.log.tsv
# Average time per optimization: 1.09 s
# Average time per condition: 3.45 s
# Total process time: 0.10 min (0.00 h)
# Final memory usage: 2136.88 MB
# Found 1 conditions to process.
#
# ============================ STARTING: Ecoli - pyr =============================
# [2026/02/07 03:36:14] Loading metabolic model: iJO1366.xml
# [2026/02/07 03:36:15] Loading transcriptomic data: Ecoli_Expfile_pyr.csv
# [2026/02/07 03:36:15] Loading known fluxes: Ecoli_knownFluxes_pyr.csv
# [2026/02/07 03:36:15] Updating model (bounds, medium)...
# Applying medium from: ./mediums/Ecoli_Medium_pyr.csv
# Starting data pre-processing...
# Capping FPKM values at 95th percentile: 23632.4075
# Median 'g' value (E_g) for imputation: 4.2129e+03
# Pre-processing finished in 0.01 seconds.
# [2026/02/07 03:36:17] Running TeraFlux optimization...
# Creating stoichiometric constraints...
# Adding known flux constraints...
# Solving with standard FBA to get an initial guess (x0)...
# R_BIOMASS_Ec_iJO1366_core_53p95M
# Adding known flux constraints...
# R_EX_pyr_e -26.714
# R_BIOMASS_Ec_iJO1366_WT_53p95M 0.39
# {'R_EX_cobalt2_e': inf, 'R_EX_h_e': inf, 'R_EX_k_e': inf, 'R_EX_cu2_e': inf, 'R_EX_mg2_e': inf, 'R_EX_mn2_e': inf, 'R_EX_mobd_e': inf, 'R_EX_nh4_e': inf, 'R_EX_ca2_e': inf, 'R_EX_cbl1_e': inf, 'R_EX_ni2_e': inf, 'R_EX_o2_e': inf, 'R_EX_cl_e': inf, 'R_EX_pi_e': inf, 'R_EX_zn2_e': inf, 'R_EX_pyr_e': 26.714, 'R_EX_so4_e': inf, 'R_EX_fe2_e': inf}
# FBA solution found. Objective value: 0.6054. Status: optimal
# ## Solving the non-linear optimization problem with IPOPT...
# Solver finished. Status: Solve_Succeeded | Success: True
# Optimization took: 1.14 s
# [2026/02/07 03:36:20] Saving results...
# [2026/02/07 03:36:20] Ecoli - pyr processed.
# ================================================================================
#
# =============================== PROCESS COMPLETE ===============================
# Summary log saved to: results/teraflux/Ecoli_pyr.log.tsv
# Average time per optimization: 1.14 s
# Average time per condition: 3.51 s
# Total process time: 0.10 min (0.00 h)
# Final memory usage: 2165.34 MB
# Found 1 conditions to process.
#
# ============================ STARTING: Ecoli - succ ============================
# [2026/02/07 03:36:20] Loading metabolic model: iJO1366.xml
# [2026/02/07 03:36:21] Loading transcriptomic data: Ecoli_Expfile_succ.csv
# [2026/02/07 03:36:21] Loading known fluxes: Ecoli_knownFluxes_succ.csv
# [2026/02/07 03:36:21] Updating model (bounds, medium)...
# Applying medium from: ./mediums/Ecoli_Medium_succ.csv
# Starting data pre-processing...
# Capping FPKM values at 95th percentile: 24010.0234
# Median 'g' value (E_g) for imputation: 4.0264e+03
# Pre-processing finished in 0.01 seconds.
# [2026/02/07 03:36:23] Running TeraFlux optimization...
# Creating stoichiometric constraints...
# Adding known flux constraints...
# Solving with standard FBA to get an initial guess (x0)...
# R_BIOMASS_Ec_iJO1366_core_53p95M
# Adding known flux constraints...
# R_EX_succ_e -15.902
# R_BIOMASS_Ec_iJO1366_WT_53p95M 0.51
# {'R_EX_cobalt2_e': inf, 'R_EX_h_e': inf, 'R_EX_k_e': inf, 'R_EX_cu2_e': inf, 'R_EX_mg2_e': inf, 'R_EX_mn2_e': inf, 'R_EX_mobd_e': inf, 'R_EX_nh4_e': inf, 'R_EX_ca2_e': inf, 'R_EX_cbl1_e': inf, 'R_EX_ni2_e': inf, 'R_EX_o2_e': inf, 'R_EX_cl_e': inf, 'R_EX_pi_e': inf, 'R_EX_zn2_e': inf, 'R_EX_so4_e': inf, 'R_EX_succ_e': 15.902, 'R_EX_fe2_e': inf}
# FBA solution found. Objective value: 0.2963. Status: optimal
# ## Solving the non-linear optimization problem with IPOPT...
# Solver finished. Status: Solve_Succeeded | Success: True
# Optimization took: 1.19 s
# [2026/02/07 03:36:26] Saving results...
# [2026/02/07 03:36:26] Ecoli - succ processed.
# ================================================================================
#
# =============================== PROCESS COMPLETE ===============================
# Summary log saved to: results/teraflux/Ecoli_succ.log.tsv
# Average time per optimization: 1.19 s
# Average time per condition: 3.57 s
# Total process time: 0.10 min (0.00 h)
# Final memory usage: 2193.01 MB

# %%
# Run teraflux with all internal fluxes being reversible

for reaction in model.reactions:
    if reaction.id in model.exchanges: continue
    reaction.bounds = (-1000,1000)
cobra.io.write_sbml_model(model,"./gems/iJO1366_allReversible.xml")   

for medium_code in medium_codes:
    # Create  InputData file
    input_file_name = f"inputData_{organism}_{medium_code}.csv"
    with open(input_file_name, 'w', newline="\n") as f:
        print("Organism\tCondition\tGeneExpFile\tMedium\tNetwork\tKnownFluxes", file=f)    
        Organism = organism
        Condition = medium_code
        GeneExpFile = f"./transcriptomes/{organism}/{organism}_Expfile_{medium_code}.csv"
        Medium =      f"./mediums/{organism}_Medium_{medium_code}.csv"
        Network = "./gems/iJO1366_allReversible.xml" 
        KnownFluxes = f"./knownFluxes/{organism}/{organism}_knownFluxes_{medium_code}.csv"
        print(Organism, Condition, GeneExpFile, Medium, Network,KnownFluxes, sep="\t", file=f)

    # Save results
    resultsDir = "./results/teraflux_allReversible/"
    prefix_log_file = f"{organism}_{medium_code}"
    ipoptParams={
            'print_level': 0, # Suppress solver output for cleaner logs
            'sb': 'yes',       # Suppress IPOPT banner
            'tol': 1e-10,       # Overall tolerance (e.g., 1e-8, 1e-10, etc.)
            'acceptable_tol': 1e-10, # Allowable tolerance before giving up
            'max_iter': 6500,   # Increase maximum iterations if needed
            'nlp_scaling_method' : 'none',
            'constr_viol_tol' : 1e-10,
            'nlp_scaling_method': 'gradient-based',
            'hessian_approximation': 'exact',
        }
    fluxes,fr,lagrange = teraflux.getFluxes(input_file_name, resultsDir, prefix_log_file, ipoptParams)

# %%
# %pwd
